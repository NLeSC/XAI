# %% [markdown]
# # Model to classify 20 tree species based on LeafSnap data subset

# %% [markdown]
# ### Settings

# %%
# Imports
import warnings
warnings.simplefilter('ignore')

import numpy as np
from numpy import load
import os.path
import matplotlib.pyplot as plt
import pandas as pd

import keras.backend as K
if(K.tensorflow_backend):
    import tensorflow as tf
    tf.logging.set_verbosity(tf.logging.ERROR)
from keras.utils import np_utils
from keras.models import load_model

from code import data as d
from code import model as m
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data and split into train, test and validation

# %%
original_data_path = "/home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/"
images_fname = os.path.join(original_data_path, "images.npz")
labels_fname = os.path.join(original_data_path, "labels.npz")
info_fname_rand = os.path.join(original_data_path, "leafsnap-dataset-20subset-images-enhanced-randomized.txt")

# load data
image_data = np.load(images_fname)
labels_data = np.load(labels_fname)
info_data = pd.read_csv(info_fname_rand)

images = image_data['images']
labels_one_hot = labels_data['labels_one_hot']


print('Image size: ', np.shape(images))
print('Labels one hot size: ', np.shape(labels_one_hot))

nim = len(labels_one_hot)
print('Number of images: ', nim)

info_data.tail()
# Out:
# Image size:  (3283, 64, 64, 3)
# Labels one hot size:  (3283, 20)
# Number of images:  3283
#              filename                   label source  label_numeric  \
# 3278  ny1016-06-4.jpg  Aesculus hippocastamon    lab              2
# 3279  ny1131-08-1.jpg     Platanus acerifolia    lab              9
# 3280  pi0020-10-3.jpg         Ulmus americana    lab             17
# 3281  pi0079-03-2.jpg            Quercus alba    lab             11
# 3282  wb1039-07-4.jpg            Betula nigra    lab              4
#
#                                                    path
# 3278  dataset/images/lab/Auto_cropped/aesculus_hippo...
# 3279  dataset/images/lab/Auto_cropped/platanus_aceri...
# 3280  dataset/images/lab/Auto_cropped/ulmus_american...
# 3281  dataset/images/lab/Auto_cropped/quercus_alba/p...
# 3282  dataset/images/lab/Auto_cropped/betula_nigra/w...

# %% [markdown]
# ### Split the data into train, test and validation

# %%
[images_train, images_val, images_test, 
 labels_one_hot_train, labels_one_hot_val, labels_one_hot_test,
 end_train_ind, end_val_ind] = d.split_data(images,labels_one_hot)
print('Image size - train set: ', np.shape(images_train))
print('Labels size - train set: ', np.shape(labels_one_hot_train)) 
print('Image size - valid. set: ', np.shape(images_val))
print('Labels size - valid. set: ', np.shape(labels_one_hot_val)) 
print('Image size - test set: ', np.shape(images_test))
print('Labels size - test set: ', np.shape(labels_one_hot_test)) 

print('Indicies: ', end_train_ind,', ', end_val_ind)
# Out:
# Image size - train set:  (2298, 64, 64, 3)
# Labels size - train set:  (2298, 20)
# Image size - valid. set:  (656, 64, 64, 3)
# Labels size - valid. set:  (656, 20)
# Image size - test set:  (329, 64, 64, 3)
# Labels size - test set:  (329, 20)
# Indicies:  2298 ,  2954

# %%
# splitting some of of the info data

labels_train = info_data.loc[:end_train_ind, "label"]
sources_train = info_data.loc[:end_train_ind, "source"]

labels_numeric_test = info_data.loc[end_val_ind:nim, "label_numeric"]
labels_test = info_data.loc[end_val_ind:nim, "label"]
filenames_test = info_data.loc[end_val_ind:nim, "filename"]
sources_test = info_data.loc[end_val_ind:nim, "source"]
path_test = info_data.loc[end_val_ind:nim, "path"]

# %% [markdown]
# ### Data formatting

# %%
img_rows = 64
img_cols = 64
img_channels = 3
#print(K.image_data_format())
if K.image_data_format() == 'channels_first':
    images_train = images_train.reshape(images_train.shape[0], img_channels, img_rows, img_cols)
    images_test = images_test.reshape(images_test.shape[0], img_channels, img_rows, img_cols)
    images_val = images_val.reshape(images_val.shape[0], img_channels, img_rows, img_cols)
    input_shape = (img_channels, img_rows, img_cols)
else:
    images_train = images_train.reshape(images_train.shape[0], img_rows, img_cols, img_channels)
    images_test = images_test.reshape(images_test.shape[0], img_rows, img_cols, img_channels)
    images_val = images_val.reshape(images_val.shape[0], img_rows, img_cols, img_channels)
    input_shape = (img_rows, img_cols, img_channels)
print("Size of training data: ", np.shape(images_train))
print("Size of validation data: ", np.shape(images_val))
print("Size of testing data: ", np.shape(images_test))
# Out:
# Size of training data:  (2298, 64, 64, 3)
# Size of validation data:  (328, 64, 64, 3)
# Size of testing data:  (657, 64, 64, 3)

# %% [markdown]
# ## Construct the model

# %%
model = m.generate_model(input_shape, 20)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_layer1 (Conv2D)       (None, 60, 60, 32)        2432
# _________________________________________________________________
# maxpooling2d_layer1 (MaxPool (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_layer2 (Conv2D)       (None, 26, 26, 64)        51264
# _________________________________________________________________
# maxpooling2d_layer2 (MaxPool (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_layer1 (Dropout)     (None, 13, 13, 64)        0
# _________________________________________________________________
# flatten_layer1 (Flatten)     (None, 10816)             0
# _________________________________________________________________
# dense_layer1 (Dense)         (None, 1000)              10817000
# _________________________________________________________________
# dropout_layer2 (Dropout)     (None, 1000)              0
# _________________________________________________________________
# dense_layer2 (Dense)         (None, 20)                20020
# =================================================================
# Total params: 10,890,716
# Trainable params: 10,890,716
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ModelCheckpoint

# autosave best Model
best_model_file = model_fname = os.path.join(original_data_path, 'Models','leafnet.h5')
best_model = ModelCheckpoint(best_model_file, monitor='val_loss', verbose=1, save_best_only=True)

print('Training model...')
batch_size = 32
epochs = 100
model, results = m.train_model(model, images_train, labels_one_hot_train,
                             images_val, labels_one_hot_val, 
                             batch_size, epochs, best_model)
print('Traing finished.')

print('Loading the best model...')
model = load_model(best_model_file)
print('Best Model loaded!')
# Out:
# Training model...
# Train on 2298 samples, validate on 328 samples
# Epoch 1/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 2.9577 - acc: 0.0970 - val_loss: 2.8903 - val_acc: 0.0976
#
# Epoch 00001: val_loss improved from inf to 2.89035, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 2/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 2.7354 - acc: 0.1823 - val_loss: 2.5352 - val_acc: 0.2134
#
# Epoch 00002: val_loss improved from 2.89035 to 2.53516, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 3/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 2.4487 - acc: 0.2576 - val_loss: 2.3693 - val_acc: 0.2591
#
# Epoch 00003: val_loss improved from 2.53516 to 2.36926, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 4/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 2.2520 - acc: 0.3198 - val_loss: 2.1122 - val_acc: 0.3567
#
# Epoch 00004: val_loss improved from 2.36926 to 2.11216, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 5/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 2.0691 - acc: 0.3699 - val_loss: 1.9182 - val_acc: 0.4024
#
# Epoch 00005: val_loss improved from 2.11216 to 1.91818, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 6/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 1.9131 - acc: 0.4178 - val_loss: 1.8275 - val_acc: 0.4390
#
# Epoch 00006: val_loss improved from 1.91818 to 1.82752, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 7/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 1.7835 - acc: 0.4539 - val_loss: 1.7073 - val_acc: 0.4238
#
# Epoch 00007: val_loss improved from 1.82752 to 1.70735, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 8/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 1.6910 - acc: 0.4774 - val_loss: 1.6597 - val_acc: 0.4787
#
# Epoch 00008: val_loss improved from 1.70735 to 1.65969, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 9/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 1.5352 - acc: 0.5257 - val_loss: 1.6040 - val_acc: 0.4604
#
# Epoch 00009: val_loss improved from 1.65969 to 1.60398, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 10/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 1.4715 - acc: 0.5357 - val_loss: 1.5698 - val_acc: 0.4939
#
# Epoch 00010: val_loss improved from 1.60398 to 1.56975, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 11/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 1.4136 - acc: 0.5583 - val_loss: 1.4442 - val_acc: 0.5396
#
# Epoch 00011: val_loss improved from 1.56975 to 1.44424, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 12/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 1.3222 - acc: 0.5788 - val_loss: 1.4164 - val_acc: 0.5457
#
# Epoch 00012: val_loss improved from 1.44424 to 1.41638, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 13/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 1.2325 - acc: 0.6005 - val_loss: 1.3427 - val_acc: 0.5488
#
# Epoch 00013: val_loss improved from 1.41638 to 1.34270, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 14/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 1.1913 - acc: 0.6131 - val_loss: 1.5205 - val_acc: 0.5091
#
# Epoch 00014: val_loss did not improve from 1.34270
# Epoch 15/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 1.1253 - acc: 0.6288 - val_loss: 1.3349 - val_acc: 0.5701
#
# Epoch 00015: val_loss improved from 1.34270 to 1.33487, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 16/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 1.0664 - acc: 0.6649 - val_loss: 1.2341 - val_acc: 0.5823
#
# Epoch 00016: val_loss improved from 1.33487 to 1.23407, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 17/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.9879 - acc: 0.6810 - val_loss: 1.2016 - val_acc: 0.5884
#
# Epoch 00017: val_loss improved from 1.23407 to 1.20160, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 18/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 1.0570 - acc: 0.6523 - val_loss: 1.1993 - val_acc: 0.5945
#
# Epoch 00018: val_loss improved from 1.20160 to 1.19933, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 19/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.9520 - acc: 0.6963 - val_loss: 1.4870 - val_acc: 0.5000
#
# Epoch 00019: val_loss did not improve from 1.19933
# Epoch 20/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.9006 - acc: 0.7045 - val_loss: 1.2315 - val_acc: 0.5854
#
# Epoch 00020: val_loss did not improve from 1.19933
# Epoch 21/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.8551 - acc: 0.7232 - val_loss: 1.1941 - val_acc: 0.5945
#
# Epoch 00021: val_loss improved from 1.19933 to 1.19415, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 22/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.7958 - acc: 0.7433 - val_loss: 1.1841 - val_acc: 0.6311
#
# Epoch 00022: val_loss improved from 1.19415 to 1.18411, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 23/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.7919 - acc: 0.7411 - val_loss: 1.1747 - val_acc: 0.6128
#
# Epoch 00023: val_loss improved from 1.18411 to 1.17467, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 24/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.7856 - acc: 0.7576 - val_loss: 1.1224 - val_acc: 0.6280
#
# Epoch 00024: val_loss improved from 1.17467 to 1.12237, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 25/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.7412 - acc: 0.7550 - val_loss: 1.3118 - val_acc: 0.5976
#
# Epoch 00025: val_loss did not improve from 1.12237
# Epoch 26/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.7319 - acc: 0.7554 - val_loss: 1.1854 - val_acc: 0.6250
#
# Epoch 00026: val_loss did not improve from 1.12237
# Epoch 27/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.7062 - acc: 0.7663 - val_loss: 1.2386 - val_acc: 0.6311
#
# Epoch 00027: val_loss did not improve from 1.12237
# Epoch 28/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.6831 - acc: 0.7815 - val_loss: 1.8691 - val_acc: 0.5244
#
# Epoch 00028: val_loss did not improve from 1.12237
# Epoch 29/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.6821 - acc: 0.7676 - val_loss: 1.1315 - val_acc: 0.6280
#
# Epoch 00029: val_loss did not improve from 1.12237
# Epoch 30/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.6523 - acc: 0.7789 - val_loss: 1.3135 - val_acc: 0.6128
#
# Epoch 00030: val_loss did not improve from 1.12237
# Epoch 31/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.5877 - acc: 0.8111 - val_loss: 1.1291 - val_acc: 0.6494
#
# Epoch 00031: val_loss did not improve from 1.12237
# Epoch 32/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.6262 - acc: 0.7916 - val_loss: 1.1798 - val_acc: 0.6341
#
# Epoch 00032: val_loss did not improve from 1.12237
# Epoch 33/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.6142 - acc: 0.7933 - val_loss: 1.1949 - val_acc: 0.6250
#
# Epoch 00033: val_loss did not improve from 1.12237
# Epoch 34/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.5439 - acc: 0.8238 - val_loss: 1.1510 - val_acc: 0.6463
#
# Epoch 00034: val_loss did not improve from 1.12237
# Epoch 35/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.5130 - acc: 0.8333 - val_loss: 1.1953 - val_acc: 0.6372
#
# Epoch 00035: val_loss did not improve from 1.12237
# Epoch 36/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.5302 - acc: 0.8259 - val_loss: 1.1249 - val_acc: 0.6433
#
# Epoch 00036: val_loss did not improve from 1.12237
# Epoch 37/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.5042 - acc: 0.8264 - val_loss: 1.2290 - val_acc: 0.6463
#
# Epoch 00037: val_loss did not improve from 1.12237
# Epoch 38/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.5043 - acc: 0.8299 - val_loss: 1.1485 - val_acc: 0.6555
#
# Epoch 00038: val_loss did not improve from 1.12237
# Epoch 39/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.5034 - acc: 0.8333 - val_loss: 1.1646 - val_acc: 0.6463
#
# Epoch 00039: val_loss did not improve from 1.12237
# Epoch 40/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.4788 - acc: 0.8446 - val_loss: 1.1168 - val_acc: 0.6585
#
# Epoch 00040: val_loss improved from 1.12237 to 1.11677, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 41/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.4680 - acc: 0.8442 - val_loss: 1.0843 - val_acc: 0.6768
#
# Epoch 00041: val_loss improved from 1.11677 to 1.08430, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 42/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.5062 - acc: 0.8346 - val_loss: 1.1413 - val_acc: 0.6463
#
# Epoch 00042: val_loss did not improve from 1.08430
# Epoch 43/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.4490 - acc: 0.8468 - val_loss: 1.1968 - val_acc: 0.6646
#
# Epoch 00043: val_loss did not improve from 1.08430
# Epoch 44/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.4814 - acc: 0.8420 - val_loss: 1.0943 - val_acc: 0.6890
#
# Epoch 00044: val_loss did not improve from 1.08430
# Epoch 45/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.4400 - acc: 0.8573 - val_loss: 1.1907 - val_acc: 0.6768
#
# Epoch 00045: val_loss did not improve from 1.08430
# Epoch 46/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.4220 - acc: 0.8512 - val_loss: 1.0422 - val_acc: 0.7043
#
# Epoch 00046: val_loss improved from 1.08430 to 1.04224, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 47/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.4221 - acc: 0.8660 - val_loss: 1.1643 - val_acc: 0.6524
#
# Epoch 00047: val_loss did not improve from 1.04224
# Epoch 48/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3907 - acc: 0.8634 - val_loss: 1.1799 - val_acc: 0.6677
#
# Epoch 00048: val_loss did not improve from 1.04224
# Epoch 49/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.4152 - acc: 0.8708 - val_loss: 1.1795 - val_acc: 0.6463
#
# Epoch 00049: val_loss did not improve from 1.04224
# Epoch 50/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3892 - acc: 0.8747 - val_loss: 1.2228 - val_acc: 0.6585
#
# Epoch 00050: val_loss did not improve from 1.04224
# Epoch 51/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.3651 - acc: 0.8795 - val_loss: 1.1900 - val_acc: 0.6524
#
# Epoch 00051: val_loss did not improve from 1.04224
# Epoch 52/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.3965 - acc: 0.8747 - val_loss: 1.1707 - val_acc: 0.6738
#
# Epoch 00052: val_loss did not improve from 1.04224
# Epoch 53/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.3456 - acc: 0.8895 - val_loss: 1.2442 - val_acc: 0.6799
#
# Epoch 00053: val_loss did not improve from 1.04224
# Epoch 54/100
# 2298/2298 [==============================] - 19s 8ms/step - loss: 0.3634 - acc: 0.8799 - val_loss: 1.2338 - val_acc: 0.6524
#
# Epoch 00054: val_loss did not improve from 1.04224
# Epoch 55/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3475 - acc: 0.8925 - val_loss: 1.2696 - val_acc: 0.6555
#
# Epoch 00055: val_loss did not improve from 1.04224
# Epoch 56/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.3623 - acc: 0.8851 - val_loss: 1.3106 - val_acc: 0.6280
#
# Epoch 00056: val_loss did not improve from 1.04224
# Epoch 57/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.3502 - acc: 0.8930 - val_loss: 1.1392 - val_acc: 0.6646
#
# Epoch 00057: val_loss did not improve from 1.04224
# Epoch 58/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3493 - acc: 0.8934 - val_loss: 1.2801 - val_acc: 0.6524
#
# Epoch 00058: val_loss did not improve from 1.04224
# Epoch 59/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3286 - acc: 0.8943 - val_loss: 1.1877 - val_acc: 0.6799
#
# Epoch 00059: val_loss did not improve from 1.04224
# Epoch 60/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.3028 - acc: 0.9047 - val_loss: 1.2943 - val_acc: 0.6768
#
# Epoch 00060: val_loss did not improve from 1.04224
# Epoch 61/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.3459 - acc: 0.8890 - val_loss: 1.1687 - val_acc: 0.6768
#
# Epoch 00061: val_loss did not improve from 1.04224
# Epoch 62/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3300 - acc: 0.8943 - val_loss: 1.2173 - val_acc: 0.6829
#
# Epoch 00062: val_loss did not improve from 1.04224
# Epoch 63/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.3149 - acc: 0.8990 - val_loss: 1.1884 - val_acc: 0.6677
#
# Epoch 00063: val_loss did not improve from 1.04224
# Epoch 64/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2999 - acc: 0.8999 - val_loss: 1.1863 - val_acc: 0.6768
#
# Epoch 00064: val_loss did not improve from 1.04224
# Epoch 65/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3060 - acc: 0.8999 - val_loss: 1.1705 - val_acc: 0.6982
#
# Epoch 00065: val_loss did not improve from 1.04224
# Epoch 66/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3040 - acc: 0.9025 - val_loss: 1.2164 - val_acc: 0.6646
#
# Epoch 00066: val_loss did not improve from 1.04224
# Epoch 67/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2775 - acc: 0.9121 - val_loss: 1.2509 - val_acc: 0.6768
#
# Epoch 00067: val_loss did not improve from 1.04224
# Epoch 68/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.2990 - acc: 0.9056 - val_loss: 1.2628 - val_acc: 0.6738
#
# Epoch 00068: val_loss did not improve from 1.04224
# Epoch 69/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.3069 - acc: 0.9003 - val_loss: 1.1907 - val_acc: 0.7012
#
# Epoch 00069: val_loss did not improve from 1.04224
# Epoch 70/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2737 - acc: 0.9091 - val_loss: 1.2006 - val_acc: 0.6921
#
# Epoch 00070: val_loss did not improve from 1.04224
# Epoch 71/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2835 - acc: 0.9003 - val_loss: 1.2698 - val_acc: 0.6585
#
# Epoch 00071: val_loss did not improve from 1.04224
# Epoch 72/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.2607 - acc: 0.9151 - val_loss: 1.3310 - val_acc: 0.6738
#
# Epoch 00072: val_loss did not improve from 1.04224
# Epoch 73/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.2281 - acc: 0.9265 - val_loss: 1.2942 - val_acc: 0.6768
#
# Epoch 00073: val_loss did not improve from 1.04224
# Epoch 74/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2754 - acc: 0.9125 - val_loss: 1.2510 - val_acc: 0.6738
#
# Epoch 00074: val_loss did not improve from 1.04224
# Epoch 75/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2676 - acc: 0.9099 - val_loss: 1.3479 - val_acc: 0.6555
#
# Epoch 00075: val_loss did not improve from 1.04224
# Epoch 76/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.2551 - acc: 0.9156 - val_loss: 1.2611 - val_acc: 0.6555
#
# Epoch 00076: val_loss did not improve from 1.04224
# Epoch 77/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.2642 - acc: 0.9169 - val_loss: 1.2068 - val_acc: 0.6860
#
# Epoch 00077: val_loss did not improve from 1.04224
# Epoch 78/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.2305 - acc: 0.9243 - val_loss: 1.3592 - val_acc: 0.6707
#
# Epoch 00078: val_loss did not improve from 1.04224
# Epoch 79/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.2730 - acc: 0.9186 - val_loss: 1.2962 - val_acc: 0.6829
#
# Epoch 00079: val_loss did not improve from 1.04224
# Epoch 80/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.2325 - acc: 0.9282 - val_loss: 1.3832 - val_acc: 0.6372
#
# Epoch 00080: val_loss did not improve from 1.04224
# Epoch 81/100
# 2298/2298 [==============================] - 1247s 543ms/step - loss: 0.2425 - acc: 0.9182 - val_loss: 1.4505 - val_acc: 0.6372
#
# Epoch 00081: val_loss did not improve from 1.04224
# Epoch 82/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.2264 - acc: 0.9247 - val_loss: 1.2915 - val_acc: 0.6646
#
# Epoch 00082: val_loss did not improve from 1.04224
# Epoch 83/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.2437 - acc: 0.9252 - val_loss: 1.3535 - val_acc: 0.6585
#
# Epoch 00083: val_loss did not improve from 1.04224
# Epoch 84/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2451 - acc: 0.9238 - val_loss: 1.3474 - val_acc: 0.6677
#
# Epoch 00084: val_loss did not improve from 1.04224
# Epoch 85/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2148 - acc: 0.9312 - val_loss: 1.3115 - val_acc: 0.6799
#
# Epoch 00085: val_loss did not improve from 1.04224
# Epoch 86/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2696 - acc: 0.9151 - val_loss: 1.2429 - val_acc: 0.6799
#
# Epoch 00086: val_loss did not improve from 1.04224
# Epoch 87/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2173 - acc: 0.9234 - val_loss: 1.2762 - val_acc: 0.6829
#
# Epoch 00087: val_loss did not improve from 1.04224
# Epoch 88/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.2219 - acc: 0.9243 - val_loss: 1.2710 - val_acc: 0.6860
#
# Epoch 00088: val_loss did not improve from 1.04224
# Epoch 89/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.2202 - acc: 0.9286 - val_loss: 1.3630 - val_acc: 0.6707
#
# Epoch 00089: val_loss did not improve from 1.04224
# Epoch 90/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2087 - acc: 0.9326 - val_loss: 1.4136 - val_acc: 0.6616
#
# Epoch 00090: val_loss did not improve from 1.04224
# Epoch 91/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2187 - acc: 0.9256 - val_loss: 1.3435 - val_acc: 0.6951
#
# Epoch 00091: val_loss did not improve from 1.04224
# Epoch 92/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2302 - acc: 0.9265 - val_loss: 1.3942 - val_acc: 0.6646
#
# Epoch 00092: val_loss did not improve from 1.04224
# Epoch 93/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2028 - acc: 0.9321 - val_loss: 1.4953 - val_acc: 0.6799
#
# Epoch 00093: val_loss did not improve from 1.04224
# Epoch 94/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.1855 - acc: 0.9356 - val_loss: 1.3645 - val_acc: 0.6829
#
# Epoch 00094: val_loss did not improve from 1.04224
# Epoch 95/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2193 - acc: 0.9238 - val_loss: 1.2857 - val_acc: 0.6799
#
# Epoch 00095: val_loss did not improve from 1.04224
# Epoch 96/100
# 2298/2298 [==============================] - 19s 8ms/step - loss: 0.2151 - acc: 0.9291 - val_loss: 1.7581 - val_acc: 0.6006
#
# Epoch 00096: val_loss did not improve from 1.04224
# Epoch 97/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2531 - acc: 0.9230 - val_loss: 1.4823 - val_acc: 0.6829
#
# Epoch 00097: val_loss did not improve from 1.04224
# Epoch 98/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.1994 - acc: 0.9386 - val_loss: 1.3594 - val_acc: 0.7043
#
# Epoch 00098: val_loss did not improve from 1.04224
# Epoch 99/100
# 2298/2298 [==============================] - 19s 8ms/step - loss: 0.2001 - acc: 0.9295 - val_loss: 1.4462 - val_acc: 0.6799
#
# Epoch 00099: val_loss did not improve from 1.04224
# Epoch 100/100
# 2298/2298 [==============================] - 19s 8ms/step - loss: 0.1843 - acc: 0.9391 - val_loss: 1.3693 - val_acc: 0.6921
#
# Epoch 00100: val_loss did not improve from 1.04224
# Traing finished.
# Loading the best model...
# Best Model loaded!

# %% [markdown]
# ### Test the model

# %%
score = model.evaluate(images_test, labels_one_hot_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.0053772831979226
# Test accuracy: 0.7275494676383845

# %% [markdown]
# ### Examine training process

# %%
print(results)
# Out:
# <keras.callbacks.History object at 0x7f7e60cea6a0>

# %%
from matplotlib import pyplot as plt

# summarize history for accuracy
plt.plot(results.history['acc'])
plt.plot(results.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper right')
plt.show()
