# %% [markdown]
# # Model to classify 30 tree species based on LeafSnap data subset

# %% [markdown]
# ### Settings

# %%
# Imports
import warnings
warnings.simplefilter('ignore')

import numpy as np
from numpy import load
import os.path
import matplotlib.pyplot as plt
import pandas as pd

import keras.backend as K
if(K.tensorflow_backend):
    import tensorflow as tf
    tf.logging.set_verbosity(tf.logging.ERROR)
from keras.utils import np_utils
from keras.models import load_model

from code import data as d
from code import model as m
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data and split into train, test and validation

# %%
original_data_path = "/home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/"
images_fname = os.path.join(original_data_path, "images.npz")
labels_fname = os.path.join(original_data_path, "labels.npz")
info_fname_rand = os.path.join(original_data_path, "leafsnap-dataset-30subset-images-enhanced-randomized.txt")

# load data
image_data = np.load(images_fname)
labels_data = np.load(labels_fname)
info_data = pd.read_csv(info_fname_rand)

images = image_data['images']
labels_one_hot = labels_data['labels_one_hot']


print('Image size: ', np.shape(images))
print('Labels one hot size: ', np.shape(labels_one_hot))

nim = len(labels_one_hot)
print('Number of images: ', nim)

info_data.tail()
# Out:
# Image size:  (6136, 64, 64, 3)
# Labels one hot size:  (6136, 30)
# Number of images:  6136
#                  filename                     label source  label_numeric  \
# 6131      pi0057-05-1.jpg           Tilia americana    lab             15
# 6132      wb1194-05-2.jpg              Betula lenta    lab              3
# 6133      pi0005-05-3.jpg         Ptelea trifoliata    lab             25
# 6134      ny1124-02-2.jpg  Broussonettia papyrifera    lab             23
# 6135  1249580214_0004.jpg      Magnolia grandiflora  field              8
#
#                                                    path
# 6131  dataset/images/lab/Auto_cropped/tilia_american...
# 6132  dataset/images/lab/Auto_cropped/betula_lenta/w...
# 6133  dataset/images/lab/Auto_cropped/ptelea_trifoli...
# 6134  dataset/images/lab/Auto_cropped/broussonettia_...
# 6135  dataset/images/field/magnolia_grandiflora/1249...

# %% [markdown]
# ### Split the data into train, test and validation

# %%
[images_train, images_val, images_test, 
 labels_one_hot_train, labels_one_hot_val, labels_one_hot_test,
 end_train_ind, end_val_ind] = d.split_data(images,labels_one_hot)
print('Image size - train set: ', np.shape(images_train))
print('Labels size - train set: ', np.shape(labels_one_hot_train)) 
print('Image size - valid. set: ', np.shape(images_val))
print('Labels size - valid. set: ', np.shape(labels_one_hot_val)) 
print('Image size - test set: ', np.shape(images_test))
print('Labels size - test set: ', np.shape(labels_one_hot_test)) 

print('Indicies: ', end_train_ind,', ', end_val_ind)
# Out:
# Image size - train set:  (4295, 64, 64, 3)
# Labels size - train set:  (4295, 30)
# Image size - valid. set:  (1227, 64, 64, 3)
# Labels size - valid. set:  (1227, 30)
# Image size - test set:  (614, 64, 64, 3)
# Labels size - test set:  (614, 30)
# Indicies:  4295 ,  5522

# %%
# splitting some of of the info data

labels_train = info_data.loc[:end_train_ind, "label"]
sources_train = info_data.loc[:end_train_ind, "source"]

labels_numeric_test = info_data.loc[end_val_ind:nim, "label_numeric"]
labels_test = info_data.loc[end_val_ind:nim, "label"]
filenames_test = info_data.loc[end_val_ind:nim, "filename"]
sources_test = info_data.loc[end_val_ind:nim, "source"]
path_test = info_data.loc[end_val_ind:nim, "path"]

# %%
# plot random train images
d.plot_12images(images_train, labels_train, sources_train, figsize=(12,10))

# %% [markdown]
# ### Data formatting

# %%
img_rows = 64
img_cols = 64
img_channels = 3
#print(K.image_data_format())
if K.image_data_format() == 'channels_first':
    images_train = images_train.reshape(images_train.shape[0], img_channels, img_rows, img_cols)
    images_test = images_test.reshape(images_test.shape[0], img_channels, img_rows, img_cols)
    images_val = images_val.reshape(images_val.shape[0], img_channels, img_rows, img_cols)
    input_shape = (img_channels, img_rows, img_cols)
else:
    images_train = images_train.reshape(images_train.shape[0], img_rows, img_cols, img_channels)
    images_test = images_test.reshape(images_test.shape[0], img_rows, img_cols, img_channels)
    images_val = images_val.reshape(images_val.shape[0], img_rows, img_cols, img_channels)
    input_shape = (img_rows, img_cols, img_channels)
print("Size of training data: ", np.shape(images_train))
print("Size of validation data: ", np.shape(images_val))
print("Size of testing data: ", np.shape(images_test))
# Out:
# Size of training data:  (4295, 64, 64, 3)
# Size of validation data:  (1227, 64, 64, 3)
# Size of testing data:  (614, 64, 64, 3)

# %% [markdown]
# ## Construct the model

# %%
model = m.generate_simpler_model(input_shape, 30)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_layer1 (Conv2D)       (None, 60, 60, 16)        1216
# _________________________________________________________________
# maxpooling2d_layer1 (MaxPool (None, 30, 30, 16)        0
# _________________________________________________________________
# conv2d_layer2 (Conv2D)       (None, 26, 26, 32)        12832
# _________________________________________________________________
# maxpooling2d_layer2 (MaxPool (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_layer1 (Dropout)     (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_layer1 (Flatten)     (None, 5408)              0
# _________________________________________________________________
# dense_layer1 (Dense)         (None, 300)               1622700
# _________________________________________________________________
# dropout_layer2 (Dropout)     (None, 300)               0
# _________________________________________________________________
# dense_layer2 (Dense)         (None, 30)                9030
# =================================================================
# Total params: 1,645,778
# Trainable params: 1,645,778
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ModelCheckpoint

# autosave best Model
best_model_file = model_fname = os.path.join(original_data_path, 'Models','leafnet.h5')
best_model = ModelCheckpoint(best_model_file, monitor='val_loss', verbose=1, save_best_only=True)

print('Training model...')
batch_size = 64
epochs = 400
model, results = m.train_model(model, images_train, labels_one_hot_train,
                             images_val, labels_one_hot_val, 
                             batch_size, epochs, best_model)
print('Traing finished.')

print('Loading the best model...')
model = load_model(best_model_file)
print('Best Model loaded!')
# Out:
# Training model...
# Train on 4295 samples, validate on 1227 samples
# Epoch 1/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 3.3844 - acc: 0.0624 - val_loss: 3.2931 - val_acc: 0.0872
#
# Epoch 00001: val_loss improved from inf to 3.29310, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 2/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 3.2210 - acc: 0.1199 - val_loss: 2.9816 - val_acc: 0.1671
#
# Epoch 00002: val_loss improved from 3.29310 to 2.98158, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 3/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 3.0455 - acc: 0.1634 - val_loss: 2.8431 - val_acc: 0.2339
#
# Epoch 00003: val_loss improved from 2.98158 to 2.84308, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 4/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 2.9067 - acc: 0.1986 - val_loss: 2.6948 - val_acc: 0.2738
#
# Epoch 00004: val_loss improved from 2.84308 to 2.69475, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 5/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.7929 - acc: 0.2293 - val_loss: 2.6570 - val_acc: 0.2559
#
# Epoch 00005: val_loss improved from 2.69475 to 2.65700, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 6/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 2.7133 - acc: 0.2438 - val_loss: 2.5159 - val_acc: 0.2885
#
# Epoch 00006: val_loss improved from 2.65700 to 2.51587, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 7/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.6659 - acc: 0.2545 - val_loss: 2.4532 - val_acc: 0.3203
#
# Epoch 00007: val_loss improved from 2.51587 to 2.45324, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 8/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.5777 - acc: 0.2782 - val_loss: 2.3884 - val_acc: 0.3244
#
# Epoch 00008: val_loss improved from 2.45324 to 2.38841, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 9/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 2.5230 - acc: 0.2915 - val_loss: 2.3504 - val_acc: 0.3293
#
# Epoch 00009: val_loss improved from 2.38841 to 2.35041, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 10/200
# 4295/4295 [==============================] - 21s 5ms/step - loss: 2.4546 - acc: 0.3006 - val_loss: 2.3048 - val_acc: 0.3399
#
# Epoch 00010: val_loss improved from 2.35041 to 2.30483, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 11/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 2.4047 - acc: 0.3176 - val_loss: 2.2435 - val_acc: 0.3553
#
# Epoch 00011: val_loss improved from 2.30483 to 2.24345, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 12/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.3584 - acc: 0.3227 - val_loss: 2.1964 - val_acc: 0.3667
#
# Epoch 00012: val_loss improved from 2.24345 to 2.19641, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 13/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.3251 - acc: 0.3304 - val_loss: 2.1587 - val_acc: 0.3757
#
# Epoch 00013: val_loss improved from 2.19641 to 2.15874, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 14/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.3010 - acc: 0.3313 - val_loss: 2.1410 - val_acc: 0.3896
#
# Epoch 00014: val_loss improved from 2.15874 to 2.14101, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 15/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.2198 - acc: 0.3588 - val_loss: 2.0920 - val_acc: 0.3888
#
# Epoch 00015: val_loss improved from 2.14101 to 2.09202, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 16/200
# 4295/4295 [==============================] - 20s 5ms/step - loss: 2.2063 - acc: 0.3614 - val_loss: 2.1065 - val_acc: 0.4010
#
# Epoch 00016: val_loss did not improve from 2.09202
# Epoch 17/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 2.1525 - acc: 0.3697 - val_loss: 2.0190 - val_acc: 0.4067
#
# Epoch 00017: val_loss improved from 2.09202 to 2.01896, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 18/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 2.1353 - acc: 0.3795 - val_loss: 1.9852 - val_acc: 0.4197
#
# Epoch 00018: val_loss improved from 2.01896 to 1.98519, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 19/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 2.0964 - acc: 0.3872 - val_loss: 1.9727 - val_acc: 0.4197
#
# Epoch 00019: val_loss improved from 1.98519 to 1.97271, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 20/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 2.0680 - acc: 0.3919 - val_loss: 1.9598 - val_acc: 0.4222
#
# Epoch 00020: val_loss improved from 1.97271 to 1.95979, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 21/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 2.0303 - acc: 0.3951 - val_loss: 1.9274 - val_acc: 0.4222
#
# Epoch 00021: val_loss improved from 1.95979 to 1.92740, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 22/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.9992 - acc: 0.4175 - val_loss: 1.9272 - val_acc: 0.4271
#
# Epoch 00022: val_loss improved from 1.92740 to 1.92722, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 23/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.9657 - acc: 0.4116 - val_loss: 1.8621 - val_acc: 0.4377
#
# Epoch 00023: val_loss improved from 1.92722 to 1.86211, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 24/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.9358 - acc: 0.4249 - val_loss: 1.8544 - val_acc: 0.4368
#
# Epoch 00024: val_loss improved from 1.86211 to 1.85440, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 25/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.9384 - acc: 0.4226 - val_loss: 1.8878 - val_acc: 0.4377
#
# Epoch 00025: val_loss did not improve from 1.85440
# Epoch 26/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.8974 - acc: 0.4317 - val_loss: 1.8077 - val_acc: 0.4613
#
# Epoch 00026: val_loss improved from 1.85440 to 1.80771, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 27/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 1.8663 - acc: 0.4403 - val_loss: 1.7862 - val_acc: 0.4613
#
# Epoch 00027: val_loss improved from 1.80771 to 1.78620, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 28/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.8482 - acc: 0.4435 - val_loss: 1.7620 - val_acc: 0.4670
#
# Epoch 00028: val_loss improved from 1.78620 to 1.76204, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 29/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.8349 - acc: 0.4489 - val_loss: 1.7471 - val_acc: 0.4605
#
# Epoch 00029: val_loss improved from 1.76204 to 1.74715, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 30/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.8285 - acc: 0.4501 - val_loss: 1.7466 - val_acc: 0.4670
#
# Epoch 00030: val_loss improved from 1.74715 to 1.74664, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 31/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.7738 - acc: 0.4631 - val_loss: 1.7055 - val_acc: 0.4898
#
# Epoch 00031: val_loss improved from 1.74664 to 1.70549, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 32/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.7581 - acc: 0.4661 - val_loss: 1.6831 - val_acc: 0.4841
#
# Epoch 00032: val_loss improved from 1.70549 to 1.68307, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 33/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.7144 - acc: 0.4771 - val_loss: 1.6650 - val_acc: 0.5061
#
# Epoch 00033: val_loss improved from 1.68307 to 1.66497, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 34/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.7028 - acc: 0.4771 - val_loss: 1.6979 - val_acc: 0.4768
#
# Epoch 00034: val_loss did not improve from 1.66497
# Epoch 35/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.6877 - acc: 0.4836 - val_loss: 1.6437 - val_acc: 0.5118
#
# Epoch 00035: val_loss improved from 1.66497 to 1.64373, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 36/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.6725 - acc: 0.4938 - val_loss: 1.6273 - val_acc: 0.5012
#
# Epoch 00036: val_loss improved from 1.64373 to 1.62727, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 37/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.6435 - acc: 0.4985 - val_loss: 1.6489 - val_acc: 0.5012
#
# Epoch 00037: val_loss did not improve from 1.62727
# Epoch 38/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.6548 - acc: 0.4973 - val_loss: 1.5852 - val_acc: 0.5232
#
# Epoch 00038: val_loss improved from 1.62727 to 1.58518, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 39/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.6205 - acc: 0.5069 - val_loss: 1.5816 - val_acc: 0.5306
#
# Epoch 00039: val_loss improved from 1.58518 to 1.58156, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 40/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.5854 - acc: 0.5143 - val_loss: 1.6029 - val_acc: 0.5167
#
# Epoch 00040: val_loss did not improve from 1.58156
# Epoch 41/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.5920 - acc: 0.5148 - val_loss: 1.5534 - val_acc: 0.5289
#
# Epoch 00041: val_loss improved from 1.58156 to 1.55336, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 42/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 1.5513 - acc: 0.5234 - val_loss: 1.5373 - val_acc: 0.5420
#
# Epoch 00042: val_loss improved from 1.55336 to 1.53726, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 43/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.5384 - acc: 0.5153 - val_loss: 1.4855 - val_acc: 0.5518
#
# Epoch 00043: val_loss improved from 1.53726 to 1.48549, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 44/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.5333 - acc: 0.5264 - val_loss: 1.5449 - val_acc: 0.5346
#
# Epoch 00044: val_loss did not improve from 1.48549
# Epoch 45/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.5084 - acc: 0.5283 - val_loss: 1.5215 - val_acc: 0.5534
#
# Epoch 00045: val_loss did not improve from 1.48549
# Epoch 46/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 1.5293 - acc: 0.5322 - val_loss: 1.4656 - val_acc: 0.5583
#
# Epoch 00046: val_loss improved from 1.48549 to 1.46559, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 47/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.4633 - acc: 0.5423 - val_loss: 1.4388 - val_acc: 0.5566
#
# Epoch 00047: val_loss improved from 1.46559 to 1.43882, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 48/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.4619 - acc: 0.5462 - val_loss: 1.4497 - val_acc: 0.5534
#
# Epoch 00048: val_loss did not improve from 1.43882
# Epoch 49/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.4365 - acc: 0.5525 - val_loss: 1.4435 - val_acc: 0.5623
#
# Epoch 00049: val_loss did not improve from 1.43882
# Epoch 50/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.4317 - acc: 0.5551 - val_loss: 1.4175 - val_acc: 0.5672
#
# Epoch 00050: val_loss improved from 1.43882 to 1.41748, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 51/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 1.3990 - acc: 0.5555 - val_loss: 1.4135 - val_acc: 0.5713
#
# Epoch 00051: val_loss improved from 1.41748 to 1.41346, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 52/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 1.4193 - acc: 0.5623 - val_loss: 1.4025 - val_acc: 0.5689
#
# Epoch 00052: val_loss improved from 1.41346 to 1.40254, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 53/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.3888 - acc: 0.5625 - val_loss: 1.4064 - val_acc: 0.5746
#
# Epoch 00053: val_loss did not improve from 1.40254
# Epoch 54/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 1.3938 - acc: 0.5602 - val_loss: 1.3829 - val_acc: 0.5762
#
# Epoch 00054: val_loss improved from 1.40254 to 1.38286, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 55/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.3677 - acc: 0.5732 - val_loss: 1.3715 - val_acc: 0.5705
#
# Epoch 00055: val_loss improved from 1.38286 to 1.37153, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 56/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.3693 - acc: 0.5625 - val_loss: 1.3961 - val_acc: 0.5721
#
# Epoch 00056: val_loss did not improve from 1.37153
# Epoch 57/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 1.3510 - acc: 0.5905 - val_loss: 1.3721 - val_acc: 0.5803
#
# Epoch 00057: val_loss did not improve from 1.37153
# Epoch 58/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.3190 - acc: 0.5842 - val_loss: 1.3769 - val_acc: 0.5713
#
# Epoch 00058: val_loss did not improve from 1.37153
# Epoch 59/200
# 4295/4295 [==============================] - 22s 5ms/step - loss: 1.3376 - acc: 0.5751 - val_loss: 1.3376 - val_acc: 0.5941
#
# Epoch 00059: val_loss improved from 1.37153 to 1.33761, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 60/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 1.2759 - acc: 0.5986 - val_loss: 1.4662 - val_acc: 0.5371
#
# Epoch 00060: val_loss did not improve from 1.33761
# Epoch 61/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.4016 - acc: 0.5586 - val_loss: 1.3365 - val_acc: 0.5892
#
# Epoch 00061: val_loss improved from 1.33761 to 1.33651, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 62/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.3015 - acc: 0.5942 - val_loss: 1.3713 - val_acc: 0.5705
#
# Epoch 00062: val_loss did not improve from 1.33651
# Epoch 63/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.2574 - acc: 0.6016 - val_loss: 1.3317 - val_acc: 0.5982
#
# Epoch 00063: val_loss improved from 1.33651 to 1.33166, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 64/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.2664 - acc: 0.6023 - val_loss: 1.3172 - val_acc: 0.5917
#
# Epoch 00064: val_loss improved from 1.33166 to 1.31715, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 65/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.2523 - acc: 0.6091 - val_loss: 1.3176 - val_acc: 0.5925
#
# Epoch 00065: val_loss did not improve from 1.31715
# Epoch 66/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.2525 - acc: 0.5981 - val_loss: 1.2848 - val_acc: 0.6055
#
# Epoch 00066: val_loss improved from 1.31715 to 1.28484, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 67/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.2308 - acc: 0.6163 - val_loss: 1.3151 - val_acc: 0.5901
#
# Epoch 00067: val_loss did not improve from 1.28484
# Epoch 68/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.2109 - acc: 0.6142 - val_loss: 1.2972 - val_acc: 0.5966
#
# Epoch 00068: val_loss did not improve from 1.28484
# Epoch 69/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.1981 - acc: 0.6284 - val_loss: 1.2333 - val_acc: 0.6104
#
# Epoch 00069: val_loss improved from 1.28484 to 1.23328, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 70/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.1971 - acc: 0.6286 - val_loss: 1.2927 - val_acc: 0.6015
#
# Epoch 00070: val_loss did not improve from 1.23328
# Epoch 71/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.1865 - acc: 0.6205 - val_loss: 1.3144 - val_acc: 0.5933
#
# Epoch 00071: val_loss did not improve from 1.23328
# Epoch 72/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1898 - acc: 0.6219 - val_loss: 1.2559 - val_acc: 0.6080
#
# Epoch 00072: val_loss did not improve from 1.23328
# Epoch 73/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1641 - acc: 0.6282 - val_loss: 1.2319 - val_acc: 0.6080
#
# Epoch 00073: val_loss improved from 1.23328 to 1.23191, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 74/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1775 - acc: 0.6293 - val_loss: 1.2492 - val_acc: 0.6170
#
# Epoch 00074: val_loss did not improve from 1.23191
# Epoch 75/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 1.1901 - acc: 0.6207 - val_loss: 1.2433 - val_acc: 0.6112
#
# Epoch 00075: val_loss did not improve from 1.23191
# Epoch 76/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.1496 - acc: 0.6352 - val_loss: 1.2174 - val_acc: 0.6145
#
# Epoch 00076: val_loss improved from 1.23191 to 1.21744, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 77/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1572 - acc: 0.6240 - val_loss: 1.2325 - val_acc: 0.6112
#
# Epoch 00077: val_loss did not improve from 1.21744
# Epoch 78/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.1370 - acc: 0.6314 - val_loss: 1.2326 - val_acc: 0.6178
#
# Epoch 00078: val_loss did not improve from 1.21744
# Epoch 79/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1127 - acc: 0.6361 - val_loss: 1.2243 - val_acc: 0.6039
#
# Epoch 00079: val_loss did not improve from 1.21744
# Epoch 80/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.1380 - acc: 0.6417 - val_loss: 1.2399 - val_acc: 0.6072
#
# Epoch 00080: val_loss did not improve from 1.21744
# Epoch 81/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.1118 - acc: 0.6368 - val_loss: 1.1967 - val_acc: 0.6243
#
# Epoch 00081: val_loss improved from 1.21744 to 1.19666, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 82/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 1.0803 - acc: 0.6533 - val_loss: 1.2045 - val_acc: 0.6104
#
# Epoch 00082: val_loss did not improve from 1.19666
# Epoch 83/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 1.1020 - acc: 0.6412 - val_loss: 1.1887 - val_acc: 0.6218
#
# Epoch 00083: val_loss improved from 1.19666 to 1.18874, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 84/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 1.1036 - acc: 0.6503 - val_loss: 1.2001 - val_acc: 0.6104
#
# Epoch 00084: val_loss did not improve from 1.18874
# Epoch 85/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 1.0781 - acc: 0.6512 - val_loss: 1.2165 - val_acc: 0.6145
#
# Epoch 00085: val_loss did not improve from 1.18874
# Epoch 86/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 1.0747 - acc: 0.6496 - val_loss: 1.1734 - val_acc: 0.6186
#
# Epoch 00086: val_loss improved from 1.18874 to 1.17345, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 87/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0515 - acc: 0.6491 - val_loss: 1.1659 - val_acc: 0.6243
#
# Epoch 00087: val_loss improved from 1.17345 to 1.16586, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 88/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.0839 - acc: 0.6549 - val_loss: 1.1947 - val_acc: 0.6202
#
# Epoch 00088: val_loss did not improve from 1.16586
# Epoch 89/200
# 4295/4295 [==============================] - 19s 5ms/step - loss: 1.0591 - acc: 0.6582 - val_loss: 1.1779 - val_acc: 0.6251
#
# Epoch 00089: val_loss did not improve from 1.16586
# Epoch 90/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 1.0516 - acc: 0.6517 - val_loss: 1.1404 - val_acc: 0.6292
#
# Epoch 00090: val_loss improved from 1.16586 to 1.14044, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 91/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.0435 - acc: 0.6657 - val_loss: 1.1485 - val_acc: 0.6333
#
# Epoch 00091: val_loss did not improve from 1.14044
# Epoch 92/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.0407 - acc: 0.6638 - val_loss: 1.1409 - val_acc: 0.6430
#
# Epoch 00092: val_loss did not improve from 1.14044
# Epoch 93/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0211 - acc: 0.6678 - val_loss: 1.1783 - val_acc: 0.6186
#
# Epoch 00093: val_loss did not improve from 1.14044
# Epoch 94/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 1.0052 - acc: 0.6724 - val_loss: 1.1310 - val_acc: 0.6300
#
# Epoch 00094: val_loss improved from 1.14044 to 1.13096, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 95/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0140 - acc: 0.6782 - val_loss: 1.1345 - val_acc: 0.6357
#
# Epoch 00095: val_loss did not improve from 1.13096
# Epoch 96/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0075 - acc: 0.6801 - val_loss: 1.1197 - val_acc: 0.6447
#
# Epoch 00096: val_loss improved from 1.13096 to 1.11972, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 97/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0015 - acc: 0.6806 - val_loss: 1.1347 - val_acc: 0.6398
#
# Epoch 00097: val_loss did not improve from 1.11972
# Epoch 98/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 1.0332 - acc: 0.6685 - val_loss: 1.1605 - val_acc: 0.6308
#
# Epoch 00098: val_loss did not improve from 1.11972
# Epoch 99/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 0.9972 - acc: 0.6778 - val_loss: 1.1119 - val_acc: 0.6430
#
# Epoch 00099: val_loss improved from 1.11972 to 1.11187, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 100/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 0.9729 - acc: 0.6817 - val_loss: 1.1812 - val_acc: 0.6161
#
# Epoch 00100: val_loss did not improve from 1.11187
# Epoch 101/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9796 - acc: 0.6859 - val_loss: 1.1226 - val_acc: 0.6512
#
# Epoch 00101: val_loss did not improve from 1.11187
# Epoch 102/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9622 - acc: 0.6850 - val_loss: 1.0906 - val_acc: 0.6406
#
# Epoch 00102: val_loss improved from 1.11187 to 1.09060, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 103/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9526 - acc: 0.6924 - val_loss: 1.1646 - val_acc: 0.6398
#
# Epoch 00103: val_loss did not improve from 1.09060
# Epoch 104/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9724 - acc: 0.6820 - val_loss: 1.1038 - val_acc: 0.6373
#
# Epoch 00104: val_loss did not improve from 1.09060
# Epoch 105/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9524 - acc: 0.6889 - val_loss: 1.0874 - val_acc: 0.6471
#
# Epoch 00105: val_loss improved from 1.09060 to 1.08739, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 106/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9365 - acc: 0.6945 - val_loss: 1.0907 - val_acc: 0.6577
#
# Epoch 00106: val_loss did not improve from 1.08739
# Epoch 107/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.9488 - acc: 0.6834 - val_loss: 1.0915 - val_acc: 0.6479
#
# Epoch 00107: val_loss did not improve from 1.08739
# Epoch 108/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.9190 - acc: 0.6999 - val_loss: 1.0743 - val_acc: 0.6536
#
# Epoch 00108: val_loss improved from 1.08739 to 1.07426, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 109/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.9221 - acc: 0.6990 - val_loss: 1.1560 - val_acc: 0.6235
#
# Epoch 00109: val_loss did not improve from 1.07426
# Epoch 110/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.8932 - acc: 0.7066 - val_loss: 1.0796 - val_acc: 0.6496
#
# Epoch 00110: val_loss did not improve from 1.07426
# Epoch 111/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.9049 - acc: 0.7045 - val_loss: 1.0610 - val_acc: 0.6634
#
# Epoch 00111: val_loss improved from 1.07426 to 1.06100, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 112/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.9211 - acc: 0.7034 - val_loss: 1.1177 - val_acc: 0.6520
#
# Epoch 00112: val_loss did not improve from 1.06100
# Epoch 113/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.9145 - acc: 0.7034 - val_loss: 1.1035 - val_acc: 0.6528
#
# Epoch 00113: val_loss did not improve from 1.06100
# Epoch 114/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.9092 - acc: 0.7078 - val_loss: 1.1093 - val_acc: 0.6536
#
# Epoch 00114: val_loss did not improve from 1.06100
# Epoch 115/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.9097 - acc: 0.7024 - val_loss: 1.0856 - val_acc: 0.6561
#
# Epoch 00115: val_loss did not improve from 1.06100
# Epoch 116/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.9101 - acc: 0.7099 - val_loss: 1.0496 - val_acc: 0.6650
#
# Epoch 00116: val_loss improved from 1.06100 to 1.04961, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 117/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8670 - acc: 0.7201 - val_loss: 1.0583 - val_acc: 0.6634
#
# Epoch 00117: val_loss did not improve from 1.04961
# Epoch 118/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.8528 - acc: 0.7192 - val_loss: 1.0506 - val_acc: 0.6667
#
# Epoch 00118: val_loss did not improve from 1.04961
# Epoch 119/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8629 - acc: 0.7190 - val_loss: 1.0694 - val_acc: 0.6553
#
# Epoch 00119: val_loss did not improve from 1.04961
# Epoch 120/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.8601 - acc: 0.7153 - val_loss: 1.0701 - val_acc: 0.6650
#
# Epoch 00120: val_loss did not improve from 1.04961
# Epoch 121/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8651 - acc: 0.7215 - val_loss: 1.0763 - val_acc: 0.6520
#
# Epoch 00121: val_loss did not improve from 1.04961
# Epoch 122/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.8878 - acc: 0.7015 - val_loss: 1.0575 - val_acc: 0.6659
#
# Epoch 00122: val_loss did not improve from 1.04961
# Epoch 123/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8713 - acc: 0.7148 - val_loss: 1.0505 - val_acc: 0.6716
#
# Epoch 00123: val_loss did not improve from 1.04961
# Epoch 124/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8115 - acc: 0.7327 - val_loss: 1.0602 - val_acc: 0.6601
#
# Epoch 00124: val_loss did not improve from 1.04961
# Epoch 125/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8314 - acc: 0.7253 - val_loss: 1.0508 - val_acc: 0.6675
#
# Epoch 00125: val_loss did not improve from 1.04961
# Epoch 126/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8372 - acc: 0.7285 - val_loss: 1.0194 - val_acc: 0.6716
#
# Epoch 00126: val_loss improved from 1.04961 to 1.01944, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 127/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8452 - acc: 0.7194 - val_loss: 1.0519 - val_acc: 0.6707
#
# Epoch 00127: val_loss did not improve from 1.01944
# Epoch 128/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8360 - acc: 0.7269 - val_loss: 1.0254 - val_acc: 0.6740
#
# Epoch 00128: val_loss did not improve from 1.01944
# Epoch 129/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8333 - acc: 0.7239 - val_loss: 1.0278 - val_acc: 0.6724
#
# Epoch 00129: val_loss did not improve from 1.01944
# Epoch 130/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.8401 - acc: 0.7171 - val_loss: 1.0283 - val_acc: 0.6732
#
# Epoch 00130: val_loss did not improve from 1.01944
# Epoch 131/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.8289 - acc: 0.7197 - val_loss: 1.0420 - val_acc: 0.6756
#
# Epoch 00131: val_loss did not improve from 1.01944
# Epoch 132/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8186 - acc: 0.7255 - val_loss: 1.0092 - val_acc: 0.6862
#
# Epoch 00132: val_loss improved from 1.01944 to 1.00921, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 133/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8086 - acc: 0.7281 - val_loss: 1.0434 - val_acc: 0.6667
#
# Epoch 00133: val_loss did not improve from 1.00921
# Epoch 134/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8338 - acc: 0.7302 - val_loss: 1.0453 - val_acc: 0.6797
#
# Epoch 00134: val_loss did not improve from 1.00921
# Epoch 135/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8090 - acc: 0.7404 - val_loss: 1.0375 - val_acc: 0.6724
#
# Epoch 00135: val_loss did not improve from 1.00921
# Epoch 136/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7962 - acc: 0.7327 - val_loss: 1.0104 - val_acc: 0.6748
#
# Epoch 00136: val_loss did not improve from 1.00921
# Epoch 137/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.8035 - acc: 0.7362 - val_loss: 1.0320 - val_acc: 0.6699
#
# Epoch 00137: val_loss did not improve from 1.00921
# Epoch 138/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7788 - acc: 0.7455 - val_loss: 1.0186 - val_acc: 0.6830
#
# Epoch 00138: val_loss did not improve from 1.00921
# Epoch 139/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7997 - acc: 0.7341 - val_loss: 1.0481 - val_acc: 0.6764
#
# Epoch 00139: val_loss did not improve from 1.00921
# Epoch 140/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7632 - acc: 0.7471 - val_loss: 1.0204 - val_acc: 0.6887
#
# Epoch 00140: val_loss did not improve from 1.00921
# Epoch 141/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.7702 - acc: 0.7355 - val_loss: 0.9900 - val_acc: 0.6862
#
# Epoch 00141: val_loss improved from 1.00921 to 0.99002, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 142/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7820 - acc: 0.7364 - val_loss: 1.0655 - val_acc: 0.6577
#
# Epoch 00142: val_loss did not improve from 0.99002
# Epoch 143/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7980 - acc: 0.7327 - val_loss: 1.0294 - val_acc: 0.6789
#
# Epoch 00143: val_loss did not improve from 0.99002
# Epoch 144/200
# 4295/4295 [==============================] - 18s 4ms/step - loss: 0.7503 - acc: 0.7467 - val_loss: 0.9904 - val_acc: 0.6830
#
# Epoch 00144: val_loss did not improve from 0.99002
# Epoch 145/200
# 4295/4295 [==============================] - 16s 4ms/step - loss: 0.7673 - acc: 0.7434 - val_loss: 0.9788 - val_acc: 0.6944
#
# Epoch 00145: val_loss improved from 0.99002 to 0.97884, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 146/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7563 - acc: 0.7448 - val_loss: 0.9762 - val_acc: 0.6985
#
# Epoch 00146: val_loss improved from 0.97884 to 0.97624, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 147/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7442 - acc: 0.7490 - val_loss: 1.0045 - val_acc: 0.6822
#
# Epoch 00147: val_loss did not improve from 0.97624
# Epoch 148/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7832 - acc: 0.7364 - val_loss: 1.0312 - val_acc: 0.6797
#
# Epoch 00148: val_loss did not improve from 0.97624
# Epoch 149/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7771 - acc: 0.7439 - val_loss: 0.9834 - val_acc: 0.6936
#
# Epoch 00149: val_loss did not improve from 0.97624
# Epoch 150/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.7398 - acc: 0.7548 - val_loss: 0.9847 - val_acc: 0.6993
#
# Epoch 00150: val_loss did not improve from 0.97624
# Epoch 151/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7445 - acc: 0.7506 - val_loss: 0.9925 - val_acc: 0.6944
#
# Epoch 00151: val_loss did not improve from 0.97624
# Epoch 152/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7489 - acc: 0.7532 - val_loss: 0.9830 - val_acc: 0.6911
#
# Epoch 00152: val_loss did not improve from 0.97624
# Epoch 153/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7312 - acc: 0.7639 - val_loss: 0.9739 - val_acc: 0.6985
#
# Epoch 00153: val_loss improved from 0.97624 to 0.97392, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 154/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7330 - acc: 0.7541 - val_loss: 0.9979 - val_acc: 0.6919
#
# Epoch 00154: val_loss did not improve from 0.97392
# Epoch 155/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7279 - acc: 0.7565 - val_loss: 0.9945 - val_acc: 0.6862
#
# Epoch 00155: val_loss did not improve from 0.97392
# Epoch 156/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7447 - acc: 0.7576 - val_loss: 1.0275 - val_acc: 0.6756
#
# Epoch 00156: val_loss did not improve from 0.97392
# Epoch 157/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7571 - acc: 0.7516 - val_loss: 0.9775 - val_acc: 0.7017
#
# Epoch 00157: val_loss did not improve from 0.97392
# Epoch 158/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7096 - acc: 0.7627 - val_loss: 1.0032 - val_acc: 0.6854
#
# Epoch 00158: val_loss did not improve from 0.97392
# Epoch 159/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7500 - acc: 0.7609 - val_loss: 0.9812 - val_acc: 0.6993
#
# Epoch 00159: val_loss did not improve from 0.97392
# Epoch 160/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7264 - acc: 0.7609 - val_loss: 0.9743 - val_acc: 0.6895
#
# Epoch 00160: val_loss did not improve from 0.97392
# Epoch 161/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7167 - acc: 0.7665 - val_loss: 0.9793 - val_acc: 0.6985
#
# Epoch 00161: val_loss did not improve from 0.97392
# Epoch 162/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7283 - acc: 0.7586 - val_loss: 1.0120 - val_acc: 0.6838
#
# Epoch 00162: val_loss did not improve from 0.97392
# Epoch 163/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7064 - acc: 0.7655 - val_loss: 0.9659 - val_acc: 0.6976
#
# Epoch 00163: val_loss improved from 0.97392 to 0.96587, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 164/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6789 - acc: 0.7816 - val_loss: 0.9798 - val_acc: 0.6879
#
# Epoch 00164: val_loss did not improve from 0.96587
# Epoch 165/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7120 - acc: 0.7611 - val_loss: 0.9739 - val_acc: 0.6968
#
# Epoch 00165: val_loss did not improve from 0.96587
# Epoch 166/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6905 - acc: 0.7700 - val_loss: 0.9825 - val_acc: 0.6944
#
# Epoch 00166: val_loss did not improve from 0.96587
# Epoch 167/200
# 4295/4295 [==============================] - 15s 4ms/step - loss: 0.6842 - acc: 0.7662 - val_loss: 1.0041 - val_acc: 0.6968
#
# Epoch 00167: val_loss did not improve from 0.96587
# Epoch 168/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7096 - acc: 0.7632 - val_loss: 0.9663 - val_acc: 0.6952
#
# Epoch 00168: val_loss did not improve from 0.96587
# Epoch 169/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6940 - acc: 0.7690 - val_loss: 1.0014 - val_acc: 0.6919
#
# Epoch 00169: val_loss did not improve from 0.96587
# Epoch 170/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7355 - acc: 0.7513 - val_loss: 1.0214 - val_acc: 0.6797
#
# Epoch 00170: val_loss did not improve from 0.96587
# Epoch 171/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6706 - acc: 0.7763 - val_loss: 0.9936 - val_acc: 0.6976
#
# Epoch 00171: val_loss did not improve from 0.96587
# Epoch 172/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6795 - acc: 0.7732 - val_loss: 0.9576 - val_acc: 0.7009
#
# Epoch 00172: val_loss improved from 0.96587 to 0.95763, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 173/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.7032 - acc: 0.7693 - val_loss: 0.9446 - val_acc: 0.6993
#
# Epoch 00173: val_loss improved from 0.95763 to 0.94461, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 174/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6909 - acc: 0.7721 - val_loss: 0.9388 - val_acc: 0.7017
#
# Epoch 00174: val_loss improved from 0.94461 to 0.93877, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 175/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6643 - acc: 0.7744 - val_loss: 0.9528 - val_acc: 0.7025
#
# Epoch 00175: val_loss did not improve from 0.93877
# Epoch 176/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6838 - acc: 0.7674 - val_loss: 0.9573 - val_acc: 0.7090
#
# Epoch 00176: val_loss did not improve from 0.93877
# Epoch 177/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6818 - acc: 0.7660 - val_loss: 0.9446 - val_acc: 0.7042
#
# Epoch 00177: val_loss did not improve from 0.93877
# Epoch 178/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6475 - acc: 0.7809 - val_loss: 0.9495 - val_acc: 0.7042
#
# Epoch 00178: val_loss did not improve from 0.93877
# Epoch 179/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6873 - acc: 0.7793 - val_loss: 0.9390 - val_acc: 0.7042
#
# Epoch 00179: val_loss did not improve from 0.93877
# Epoch 180/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6550 - acc: 0.7776 - val_loss: 0.9549 - val_acc: 0.7107
#
# Epoch 00180: val_loss did not improve from 0.93877
# Epoch 181/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6566 - acc: 0.7776 - val_loss: 0.9697 - val_acc: 0.7050
#
# Epoch 00181: val_loss did not improve from 0.93877
# Epoch 182/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6613 - acc: 0.7800 - val_loss: 0.9533 - val_acc: 0.7115
#
# Epoch 00182: val_loss did not improve from 0.93877
# Epoch 183/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6713 - acc: 0.7749 - val_loss: 0.9610 - val_acc: 0.7025
#
# Epoch 00183: val_loss did not improve from 0.93877
# Epoch 184/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.7278 - acc: 0.7590 - val_loss: 0.9182 - val_acc: 0.7139
#
# Epoch 00184: val_loss improved from 0.93877 to 0.91824, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 185/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6355 - acc: 0.7849 - val_loss: 0.9317 - val_acc: 0.7139
#
# Epoch 00185: val_loss did not improve from 0.91824
# Epoch 186/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6398 - acc: 0.7891 - val_loss: 0.9337 - val_acc: 0.7107
#
# Epoch 00186: val_loss did not improve from 0.91824
# Epoch 187/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6726 - acc: 0.7758 - val_loss: 0.9675 - val_acc: 0.6985
#
# Epoch 00187: val_loss did not improve from 0.91824
# Epoch 188/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6252 - acc: 0.7972 - val_loss: 0.9329 - val_acc: 0.7180
#
# Epoch 00188: val_loss did not improve from 0.91824
# Epoch 189/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6474 - acc: 0.7814 - val_loss: 0.9865 - val_acc: 0.6870
#
# Epoch 00189: val_loss did not improve from 0.91824
# Epoch 190/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6589 - acc: 0.7825 - val_loss: 0.9304 - val_acc: 0.7107
#
# Epoch 00190: val_loss did not improve from 0.91824
# Epoch 191/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6302 - acc: 0.7877 - val_loss: 0.9698 - val_acc: 0.7001
#
# Epoch 00191: val_loss did not improve from 0.91824
# Epoch 192/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6288 - acc: 0.7898 - val_loss: 0.9774 - val_acc: 0.7009
#
# Epoch 00192: val_loss did not improve from 0.91824
# Epoch 193/200
# 4295/4295 [==============================] - 15s 3ms/step - loss: 0.6329 - acc: 0.7902 - val_loss: 0.9515 - val_acc: 0.7090
#
# Epoch 00193: val_loss did not improve from 0.91824
# Epoch 194/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6645 - acc: 0.7709 - val_loss: 0.9127 - val_acc: 0.7148
#
# Epoch 00194: val_loss improved from 0.91824 to 0.91269, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-30subset/Models/leafnet.h5
# Epoch 195/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6366 - acc: 0.7909 - val_loss: 0.9633 - val_acc: 0.6960
#
# Epoch 00195: val_loss did not improve from 0.91269
# Epoch 196/200
# 4295/4295 [==============================] - 14s 3ms/step - loss: 0.6544 - acc: 0.7772 - val_loss: 0.9381 - val_acc: 0.7017
#
# Epoch 00196: val_loss did not improve from 0.91269
# Epoch 197/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 0.6626 - acc: 0.7821 - val_loss: 0.9152 - val_acc: 0.7229
#
# Epoch 00197: val_loss did not improve from 0.91269
# Epoch 198/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 0.6037 - acc: 0.7944 - val_loss: 0.9391 - val_acc: 0.7156
#
# Epoch 00198: val_loss did not improve from 0.91269
# Epoch 199/200
# 4295/4295 [==============================] - 19s 4ms/step - loss: 0.6164 - acc: 0.7932 - val_loss: 0.9300 - val_acc: 0.7123
#
# Epoch 00199: val_loss did not improve from 0.91269
# Epoch 200/200
# 4295/4295 [==============================] - 17s 4ms/step - loss: 0.6056 - acc: 0.7951 - val_loss: 0.9411 - val_acc: 0.7156
#
# Epoch 00200: val_loss did not improve from 0.91269
# Traing finished.
# Loading the best model...
# Best Model loaded!

# %% [markdown]
# ### Test the model

# %%
score = model.evaluate(images_test, labels_one_hot_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.9802564279652574
# Test accuracy: 0.7117263845589727

# %% [markdown]
# ### Examine training process

# %%
print(results)
# Out:
# <keras.callbacks.History object at 0x7fdd5634e6a0>

# %%
from matplotlib import pyplot as plt

# summarize history for accuracy
plt.plot(results.history['acc'])
plt.plot(results.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper right')
plt.show()
