# %% [markdown]
# # Model to classify 20 tree species based on LeafSnap data subset

# %% [markdown]
# ### Settings

# %%
# Imports
import warnings
warnings.simplefilter('ignore')

import numpy as np
from numpy import load
import os.path
import matplotlib.pyplot as plt
import pandas as pd

import keras.backend as K
if(K.tensorflow_backend):
    import tensorflow as tf
    tf.logging.set_verbosity(tf.logging.ERROR)
from keras.utils import np_utils
from keras.models import load_model

from code import data as d
from code import model as m
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data and split into train, test and validation

# %%
original_data_path = "/home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/"
images_fname = os.path.join(original_data_path, "images.npz")
labels_fname = os.path.join(original_data_path, "labels.npz")
info_fname_rand = os.path.join(original_data_path, "leafsnap-dataset-20subset-images-enhanced-randomized.txt")

# load data
image_data = np.load(images_fname)
labels_data = np.load(labels_fname)
info_data = pd.read_csv(info_fname_rand)

images = image_data['images']
labels_one_hot = labels_data['labels_one_hot']


print('Image size: ', np.shape(images))
print('Labels one hot size: ', np.shape(labels_one_hot))

nim = len(labels_one_hot)
print('Number of images: ', nim)

info_data.tail()
# Out:
# Image size:  (3283, 64, 64, 3)
# Labels one hot size:  (3283, 20)
# Number of images:  3283
#                 filename                 label source  label_numeric  \
# 3278  13002204347915.jpg           Salix nigra  field             14
# 3279     wb1193-06-2.jpg          Betula lenta    lab              3
# 3280  13002204347905.jpg           Salix nigra  field             14
# 3281     wb1220-03-2.jpg    Magnolia acuminata    lab              7
# 3282     pi2201-01-1.jpg  Diospyros virginiana    lab              6
#
#                                                    path
# 3278  dataset/images/field/salix_nigra/1300220434791...
# 3279  dataset/images/lab/Auto_cropped/betula_lenta/w...
# 3280  dataset/images/field/salix_nigra/1300220434790...
# 3281  dataset/images/lab/Auto_cropped/magnolia_acumi...
# 3282  dataset/images/lab/Auto_cropped/diospyros_virg...

# %% [markdown]
# ### Split the data into train, test and validation

# %%
[images_train, images_val, images_test, 
 labels_one_hot_train, labels_one_hot_val, labels_one_hot_test,
 end_train_ind, end_val_ind] = d.split_data(images,labels_one_hot)
print('Image size - train set: ', np.shape(images_train))
print('Labels size - train set: ', np.shape(labels_one_hot_train)) 
print('Image size - valid. set: ', np.shape(images_val))
print('Labels size - valid. set: ', np.shape(labels_one_hot_val)) 
print('Image size - test set: ', np.shape(images_test))
print('Labels size - test set: ', np.shape(labels_one_hot_test)) 

print('Indicies: ', end_train_ind,', ', end_val_ind)
# Out:
# Image size - train set:  (2298, 64, 64, 3)
# Labels size - train set:  (2298, 20)
# Image size - valid. set:  (328, 64, 64, 3)
# Labels size - valid. set:  (328, 20)
# Image size - test set:  (657, 64, 64, 3)
# Labels size - test set:  (657, 20)
# Indicies:  2298 ,  2626

# %%
# splitting some of of the info data

labels_train = info_data.loc[:end_train_ind, "label"]
sources_train = info_data.loc[:end_train_ind, "source"]

labels_numeric_test = info_data.loc[end_val_ind:nim, "label_numeric"]
labels_test = info_data.loc[end_val_ind:nim, "label"]
filenames_test = info_data.loc[end_val_ind:nim, "filename"]
sources_test = info_data.loc[end_val_ind:nim, "source"]
path_test = info_data.loc[end_val_ind:nim, "path"]

# %%
# plot random train images
d.plot_12images(images_train, labels_train, sources_train, figsize=(12,10))

# %% [markdown]
# ### Data formatting

# %%
img_rows = 64
img_cols = 64
img_channels = 3
#print(K.image_data_format())
if K.image_data_format() == 'channels_first':
    images_train = images_train.reshape(images_train.shape[0], img_channels, img_rows, img_cols)
    images_test = images_test.reshape(images_test.shape[0], img_channels, img_rows, img_cols)
    images_val = images_val.reshape(images_val.shape[0], img_channels, img_rows, img_cols)
    input_shape = (img_channels, img_rows, img_cols)
else:
    images_train = images_train.reshape(images_train.shape[0], img_rows, img_cols, img_channels)
    images_test = images_test.reshape(images_test.shape[0], img_rows, img_cols, img_channels)
    images_val = images_val.reshape(images_val.shape[0], img_rows, img_cols, img_channels)
    input_shape = (img_rows, img_cols, img_channels)
print("Size of training data: ", np.shape(images_train))
print("Size of validation data: ", np.shape(images_val))
print("Size of testing data: ", np.shape(images_test))
# Out:
# Size of training data:  (2298, 64, 64, 3)
# Size of validation data:  (328, 64, 64, 3)
# Size of testing data:  (657, 64, 64, 3)

# %% [markdown]
# ## Construct the model

# %%
model = m.generate_model(input_shape, 20)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_layer1 (Conv2D)       (None, 60, 60, 16)        1216
# _________________________________________________________________
# conv2d_layer2 (Conv2D)       (None, 56, 56, 32)        12832
# _________________________________________________________________
# maxpooling2d_layer1 (MaxPool (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_layer1 (Dropout)     (None, 28, 28, 32)        0
# _________________________________________________________________
# flatten_layer1 (Flatten)     (None, 25088)             0
# _________________________________________________________________
# dense_layer1 (Dense)         (None, 100)               2508900
# _________________________________________________________________
# dropout_layer2 (Dropout)     (None, 100)               0
# _________________________________________________________________
# dense_layer2 (Dense)         (None, 20)                2020
# =================================================================
# Total params: 2,524,968
# Trainable params: 2,524,968
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ModelCheckpoint

# autosave best Model
best_model_file = model_fname = os.path.join(original_data_path, 'Models','leafnet.h5')
best_model = ModelCheckpoint(best_model_file, monitor='val_loss', verbose=1, save_best_only=True)

print('Training model...')
batch_size = 32
epochs = 100
model, results = m.train_model(model, images_train, labels_one_hot_train,
                             images_val, labels_one_hot_val, 
                             batch_size, epochs, best_model)
print('Traing finished.')

print('Loading the best model...')
model = load_model(best_model_file)
print('Best Model loaded!')
# Out:
# Training model...
# Train on 2298 samples, validate on 328 samples
# Epoch 1/100
# 2298/2298 [==============================] - 29s 13ms/step - loss: 3.0308 - acc: 0.0836 - val_loss: 2.8920 - val_acc: 0.1311
#
# Epoch 00001: val_loss improved from inf to 2.89196, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 2/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 2.8272 - acc: 0.1432 - val_loss: 2.6367 - val_acc: 0.2317
#
# Epoch 00002: val_loss improved from 2.89196 to 2.63667, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 3/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 2.5615 - acc: 0.2254 - val_loss: 2.3709 - val_acc: 0.3171
#
# Epoch 00003: val_loss improved from 2.63667 to 2.37086, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 4/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 2.3543 - acc: 0.2924 - val_loss: 2.2787 - val_acc: 0.3201
#
# Epoch 00004: val_loss improved from 2.37086 to 2.27869, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 5/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 2.1078 - acc: 0.3799 - val_loss: 2.0431 - val_acc: 0.3780
#
# Epoch 00005: val_loss improved from 2.27869 to 2.04308, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 6/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 1.9330 - acc: 0.4117 - val_loss: 1.9978 - val_acc: 0.4146
#
# Epoch 00006: val_loss improved from 2.04308 to 1.99784, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 7/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 1.7505 - acc: 0.4608 - val_loss: 1.8593 - val_acc: 0.4329
#
# Epoch 00007: val_loss improved from 1.99784 to 1.85933, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 8/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 1.5805 - acc: 0.5057 - val_loss: 1.8235 - val_acc: 0.4055
#
# Epoch 00008: val_loss improved from 1.85933 to 1.82352, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 9/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 1.4425 - acc: 0.5466 - val_loss: 1.9147 - val_acc: 0.3994
#
# Epoch 00009: val_loss did not improve from 1.82352
# Epoch 10/100
# 2298/2298 [==============================] - 29s 12ms/step - loss: 1.2579 - acc: 0.5970 - val_loss: 1.6721 - val_acc: 0.4878
#
# Epoch 00010: val_loss improved from 1.82352 to 1.67214, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 11/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 1.1405 - acc: 0.6314 - val_loss: 1.6350 - val_acc: 0.4909
#
# Epoch 00011: val_loss improved from 1.67214 to 1.63497, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 12/100
# 2298/2298 [==============================] - 28s 12ms/step - loss: 1.0742 - acc: 0.6614 - val_loss: 1.6391 - val_acc: 0.4909
#
# Epoch 00012: val_loss did not improve from 1.63497
# Epoch 13/100
# 2298/2298 [==============================] - 28s 12ms/step - loss: 0.9484 - acc: 0.6915 - val_loss: 1.6201 - val_acc: 0.5122
#
# Epoch 00013: val_loss improved from 1.63497 to 1.62014, saving model to /home/elena/eStep/XAI/Data/LeafSnap/leafsnap-dataset-20subset/Models/leafnet.h5
# Epoch 14/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 0.8605 - acc: 0.7267 - val_loss: 1.6328 - val_acc: 0.5335
#
# Epoch 00014: val_loss did not improve from 1.62014
# Epoch 15/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.8346 - acc: 0.7298 - val_loss: 1.6511 - val_acc: 0.5335
#
# Epoch 00015: val_loss did not improve from 1.62014
# Epoch 16/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 0.7543 - acc: 0.7572 - val_loss: 1.6765 - val_acc: 0.5213
#
# Epoch 00016: val_loss did not improve from 1.62014
# Epoch 17/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.7232 - acc: 0.7541 - val_loss: 1.7475 - val_acc: 0.5183
#
# Epoch 00017: val_loss did not improve from 1.62014
# Epoch 18/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.6345 - acc: 0.7863 - val_loss: 2.2873 - val_acc: 0.3780
#
# Epoch 00018: val_loss did not improve from 1.62014
# Epoch 19/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.5805 - acc: 0.8111 - val_loss: 1.7327 - val_acc: 0.5335
#
# Epoch 00019: val_loss did not improve from 1.62014
# Epoch 20/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.5427 - acc: 0.8285 - val_loss: 1.8796 - val_acc: 0.4878
#
# Epoch 00020: val_loss did not improve from 1.62014
# Epoch 21/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.4980 - acc: 0.8312 - val_loss: 1.8588 - val_acc: 0.5244
#
# Epoch 00021: val_loss did not improve from 1.62014
# Epoch 22/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.4910 - acc: 0.8438 - val_loss: 2.0798 - val_acc: 0.4665
#
# Epoch 00022: val_loss did not improve from 1.62014
# Epoch 23/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.4321 - acc: 0.8594 - val_loss: 1.7951 - val_acc: 0.5518
#
# Epoch 00023: val_loss did not improve from 1.62014
# Epoch 24/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.4036 - acc: 0.8634 - val_loss: 1.9383 - val_acc: 0.5427
#
# Epoch 00024: val_loss did not improve from 1.62014
# Epoch 25/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.3986 - acc: 0.8686 - val_loss: 1.9427 - val_acc: 0.5000
#
# Epoch 00025: val_loss did not improve from 1.62014
# Epoch 26/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.3726 - acc: 0.8773 - val_loss: 2.0024 - val_acc: 0.5183
#
# Epoch 00026: val_loss did not improve from 1.62014
# Epoch 27/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.3252 - acc: 0.8999 - val_loss: 1.9658 - val_acc: 0.5579
#
# Epoch 00027: val_loss did not improve from 1.62014
# Epoch 28/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.3402 - acc: 0.8851 - val_loss: 2.0066 - val_acc: 0.5518
#
# Epoch 00028: val_loss did not improve from 1.62014
# Epoch 29/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.2666 - acc: 0.9117 - val_loss: 2.0881 - val_acc: 0.5732
#
# Epoch 00029: val_loss did not improve from 1.62014
# Epoch 30/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.2910 - acc: 0.9008 - val_loss: 2.0197 - val_acc: 0.5457
#
# Epoch 00030: val_loss did not improve from 1.62014
# Epoch 31/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2622 - acc: 0.9082 - val_loss: 2.0907 - val_acc: 0.5274
#
# Epoch 00031: val_loss did not improve from 1.62014
# Epoch 32/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.2766 - acc: 0.9112 - val_loss: 2.1728 - val_acc: 0.5488
#
# Epoch 00032: val_loss did not improve from 1.62014
# Epoch 33/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.2440 - acc: 0.9164 - val_loss: 2.2796 - val_acc: 0.5335
#
# Epoch 00033: val_loss did not improve from 1.62014
# Epoch 34/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.2163 - acc: 0.9347 - val_loss: 2.3401 - val_acc: 0.5488
#
# Epoch 00034: val_loss did not improve from 1.62014
# Epoch 35/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.2380 - acc: 0.9186 - val_loss: 2.3533 - val_acc: 0.5244
#
# Epoch 00035: val_loss did not improve from 1.62014
# Epoch 36/100
# 2298/2298 [==============================] - 32s 14ms/step - loss: 0.2248 - acc: 0.9317 - val_loss: 2.2630 - val_acc: 0.5244
#
# Epoch 00036: val_loss did not improve from 1.62014
# Epoch 37/100
# 2298/2298 [==============================] - 38s 17ms/step - loss: 0.2210 - acc: 0.9252 - val_loss: 2.2869 - val_acc: 0.5549
#
# Epoch 00037: val_loss did not improve from 1.62014
# Epoch 38/100
# 2298/2298 [==============================] - 31s 14ms/step - loss: 0.2160 - acc: 0.9295 - val_loss: 2.2920 - val_acc: 0.5579
#
# Epoch 00038: val_loss did not improve from 1.62014
# Epoch 39/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.1736 - acc: 0.9417 - val_loss: 2.4485 - val_acc: 0.5244
#
# Epoch 00039: val_loss did not improve from 1.62014
# Epoch 40/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1715 - acc: 0.9417 - val_loss: 2.3472 - val_acc: 0.5457
#
# Epoch 00040: val_loss did not improve from 1.62014
# Epoch 41/100
# 2298/2298 [==============================] - 28s 12ms/step - loss: 0.1904 - acc: 0.9321 - val_loss: 2.5536 - val_acc: 0.5335
#
# Epoch 00041: val_loss did not improve from 1.62014
# Epoch 42/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 0.1884 - acc: 0.9330 - val_loss: 2.4252 - val_acc: 0.5244
#
# Epoch 00042: val_loss did not improve from 1.62014
# Epoch 43/100
# 2298/2298 [==============================] - 41s 18ms/step - loss: 0.1815 - acc: 0.9399 - val_loss: 2.5587 - val_acc: 0.5274
#
# Epoch 00043: val_loss did not improve from 1.62014
# Epoch 44/100
# 2298/2298 [==============================] - 36s 16ms/step - loss: 0.1744 - acc: 0.9473 - val_loss: 2.4504 - val_acc: 0.5122
#
# Epoch 00044: val_loss did not improve from 1.62014
# Epoch 45/100
# 2298/2298 [==============================] - 37s 16ms/step - loss: 0.1434 - acc: 0.9552 - val_loss: 2.5663 - val_acc: 0.5213
#
# Epoch 00045: val_loss did not improve from 1.62014
# Epoch 46/100
# 2298/2298 [==============================] - 35s 15ms/step - loss: 0.1441 - acc: 0.9491 - val_loss: 2.6799 - val_acc: 0.5152
#
# Epoch 00046: val_loss did not improve from 1.62014
# Epoch 47/100
# 2298/2298 [==============================] - 39s 17ms/step - loss: 0.1418 - acc: 0.9565 - val_loss: 2.6694 - val_acc: 0.5183
#
# Epoch 00047: val_loss did not improve from 1.62014
# Epoch 48/100
# 2298/2298 [==============================] - 31s 13ms/step - loss: 0.1514 - acc: 0.9469 - val_loss: 2.6220 - val_acc: 0.5762
#
# Epoch 00048: val_loss did not improve from 1.62014
# Epoch 49/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1445 - acc: 0.9560 - val_loss: 2.7985 - val_acc: 0.5488
#
# Epoch 00049: val_loss did not improve from 1.62014
# Epoch 50/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.1261 - acc: 0.9587 - val_loss: 2.6085 - val_acc: 0.5579
#
# Epoch 00050: val_loss did not improve from 1.62014
# Epoch 51/100
# 2298/2298 [==============================] - 30s 13ms/step - loss: 0.1304 - acc: 0.9565 - val_loss: 2.6663 - val_acc: 0.5488
#
# Epoch 00051: val_loss did not improve from 1.62014
# Epoch 52/100
# 2298/2298 [==============================] - 30s 13ms/step - loss: 0.1488 - acc: 0.9513 - val_loss: 2.5059 - val_acc: 0.5457
#
# Epoch 00052: val_loss did not improve from 1.62014
# Epoch 53/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.1431 - acc: 0.9491 - val_loss: 2.6690 - val_acc: 0.5244
#
# Epoch 00053: val_loss did not improve from 1.62014
# Epoch 54/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1257 - acc: 0.9552 - val_loss: 2.8049 - val_acc: 0.5183
#
# Epoch 00054: val_loss did not improve from 1.62014
# Epoch 55/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.1263 - acc: 0.9556 - val_loss: 2.8229 - val_acc: 0.5366
#
# Epoch 00055: val_loss did not improve from 1.62014
# Epoch 56/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.1095 - acc: 0.9648 - val_loss: 2.8247 - val_acc: 0.5396
#
# Epoch 00056: val_loss did not improve from 1.62014
# Epoch 57/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.1230 - acc: 0.9600 - val_loss: 2.8650 - val_acc: 0.5427
#
# Epoch 00057: val_loss did not improve from 1.62014
# Epoch 58/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.1163 - acc: 0.9613 - val_loss: 2.8409 - val_acc: 0.5183
#
# Epoch 00058: val_loss did not improve from 1.62014
# Epoch 59/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.1290 - acc: 0.9595 - val_loss: 3.0091 - val_acc: 0.5427
#
# Epoch 00059: val_loss did not improve from 1.62014
# Epoch 60/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1263 - acc: 0.9560 - val_loss: 2.8289 - val_acc: 0.5244
#
# Epoch 00060: val_loss did not improve from 1.62014
# Epoch 61/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1154 - acc: 0.9626 - val_loss: 2.7822 - val_acc: 0.5366
#
# Epoch 00061: val_loss did not improve from 1.62014
# Epoch 62/100
# 2298/2298 [==============================] - 28s 12ms/step - loss: 0.1196 - acc: 0.9608 - val_loss: 2.8285 - val_acc: 0.5244
#
# Epoch 00062: val_loss did not improve from 1.62014
# Epoch 63/100
# 2298/2298 [==============================] - 30s 13ms/step - loss: 0.1251 - acc: 0.9643 - val_loss: 2.8063 - val_acc: 0.5244
#
# Epoch 00063: val_loss did not improve from 1.62014
# Epoch 64/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.1269 - acc: 0.9604 - val_loss: 3.0979 - val_acc: 0.5061
#
# Epoch 00064: val_loss did not improve from 1.62014
# Epoch 65/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.1100 - acc: 0.9613 - val_loss: 2.9032 - val_acc: 0.5427
#
# Epoch 00065: val_loss did not improve from 1.62014
# Epoch 66/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.1039 - acc: 0.9700 - val_loss: 2.8234 - val_acc: 0.5244
#
# Epoch 00066: val_loss did not improve from 1.62014
# Epoch 67/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.1050 - acc: 0.9721 - val_loss: 2.8724 - val_acc: 0.5427
#
# Epoch 00067: val_loss did not improve from 1.62014
# Epoch 68/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.0955 - acc: 0.9678 - val_loss: 2.8874 - val_acc: 0.5427
#
# Epoch 00068: val_loss did not improve from 1.62014
# Epoch 69/100
# 2298/2298 [==============================] - 26s 11ms/step - loss: 0.1033 - acc: 0.9661 - val_loss: 2.7668 - val_acc: 0.5335
#
# Epoch 00069: val_loss did not improve from 1.62014
# Epoch 70/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.0854 - acc: 0.9717 - val_loss: 2.9290 - val_acc: 0.5579
#
# Epoch 00070: val_loss did not improve from 1.62014
# Epoch 71/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.0970 - acc: 0.9652 - val_loss: 2.9009 - val_acc: 0.5518
#
# Epoch 00071: val_loss did not improve from 1.62014
# Epoch 72/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.0846 - acc: 0.9761 - val_loss: 2.8391 - val_acc: 0.5427
#
# Epoch 00072: val_loss did not improve from 1.62014
# Epoch 73/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1031 - acc: 0.9643 - val_loss: 2.9588 - val_acc: 0.5518
#
# Epoch 00073: val_loss did not improve from 1.62014
# Epoch 74/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.0786 - acc: 0.9752 - val_loss: 2.7784 - val_acc: 0.5549
#
# Epoch 00074: val_loss did not improve from 1.62014
# Epoch 75/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.1034 - acc: 0.9700 - val_loss: 2.9465 - val_acc: 0.5549
#
# Epoch 00075: val_loss did not improve from 1.62014
# Epoch 76/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.0866 - acc: 0.9752 - val_loss: 3.2948 - val_acc: 0.5152
#
# Epoch 00076: val_loss did not improve from 1.62014
# Epoch 77/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.0796 - acc: 0.9748 - val_loss: 2.9875 - val_acc: 0.5427
#
# Epoch 00077: val_loss did not improve from 1.62014
# Epoch 78/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.1181 - acc: 0.9587 - val_loss: 3.2493 - val_acc: 0.5183
#
# Epoch 00078: val_loss did not improve from 1.62014
# Epoch 79/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.1148 - acc: 0.9656 - val_loss: 3.0518 - val_acc: 0.5335
#
# Epoch 00079: val_loss did not improve from 1.62014
# Epoch 80/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.0743 - acc: 0.9739 - val_loss: 2.9947 - val_acc: 0.5549
#
# Epoch 00080: val_loss did not improve from 1.62014
# Epoch 81/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.0999 - acc: 0.9700 - val_loss: 2.9049 - val_acc: 0.5518
#
# Epoch 00081: val_loss did not improve from 1.62014
# Epoch 82/100
# 2298/2298 [==============================] - 24s 10ms/step - loss: 0.0613 - acc: 0.9778 - val_loss: 3.0055 - val_acc: 0.5823
#
# Epoch 00082: val_loss did not improve from 1.62014
# Epoch 83/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.1084 - acc: 0.9687 - val_loss: 3.0854 - val_acc: 0.5579
#
# Epoch 00083: val_loss did not improve from 1.62014
# Epoch 84/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.0850 - acc: 0.9682 - val_loss: 3.0548 - val_acc: 0.5549
#
# Epoch 00084: val_loss did not improve from 1.62014
# Epoch 85/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.0791 - acc: 0.9774 - val_loss: 3.2299 - val_acc: 0.5701
#
# Epoch 00085: val_loss did not improve from 1.62014
# Epoch 86/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.0607 - acc: 0.9813 - val_loss: 3.1201 - val_acc: 0.5610
#
# Epoch 00086: val_loss did not improve from 1.62014
# Epoch 87/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0723 - acc: 0.9765 - val_loss: 2.9663 - val_acc: 0.5610
#
# Epoch 00087: val_loss did not improve from 1.62014
# Epoch 88/100
# 2298/2298 [==============================] - 22s 9ms/step - loss: 0.1043 - acc: 0.9656 - val_loss: 3.2769 - val_acc: 0.5396
#
# Epoch 00088: val_loss did not improve from 1.62014
# Epoch 89/100
# 2298/2298 [==============================] - 23s 10ms/step - loss: 0.1001 - acc: 0.9713 - val_loss: 2.9856 - val_acc: 0.5549
#
# Epoch 00089: val_loss did not improve from 1.62014
# Epoch 90/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0716 - acc: 0.9765 - val_loss: 2.9785 - val_acc: 0.5427
#
# Epoch 00090: val_loss did not improve from 1.62014
# Epoch 91/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0832 - acc: 0.9704 - val_loss: 3.1218 - val_acc: 0.5396
#
# Epoch 00091: val_loss did not improve from 1.62014
# Epoch 92/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0874 - acc: 0.9704 - val_loss: 3.0480 - val_acc: 0.5427
#
# Epoch 00092: val_loss did not improve from 1.62014
# Epoch 93/100
# 2298/2298 [==============================] - 20s 9ms/step - loss: 0.0687 - acc: 0.9756 - val_loss: 3.2805 - val_acc: 0.5518
#
# Epoch 00093: val_loss did not improve from 1.62014
# Epoch 94/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0617 - acc: 0.9809 - val_loss: 3.3223 - val_acc: 0.5640
#
# Epoch 00094: val_loss did not improve from 1.62014
# Epoch 95/100
# 2298/2298 [==============================] - 21s 9ms/step - loss: 0.0866 - acc: 0.9726 - val_loss: 3.0784 - val_acc: 0.5549
#
# Epoch 00095: val_loss did not improve from 1.62014
# Epoch 96/100
# 2298/2298 [==============================] - 24s 11ms/step - loss: 0.0935 - acc: 0.9700 - val_loss: 3.0476 - val_acc: 0.5732
#
# Epoch 00096: val_loss did not improve from 1.62014
# Epoch 97/100
# 2298/2298 [==============================] - 22s 10ms/step - loss: 0.0656 - acc: 0.9774 - val_loss: 3.2412 - val_acc: 0.5610
#
# Epoch 00097: val_loss did not improve from 1.62014
# Epoch 98/100
# 2298/2298 [==============================] - 27s 12ms/step - loss: 0.0790 - acc: 0.9726 - val_loss: 3.2830 - val_acc: 0.5366
#
# Epoch 00098: val_loss did not improve from 1.62014
# Epoch 99/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.0746 - acc: 0.9774 - val_loss: 3.0322 - val_acc: 0.5732
#
# Epoch 00099: val_loss did not improve from 1.62014
# Epoch 100/100
# 2298/2298 [==============================] - 25s 11ms/step - loss: 0.0729 - acc: 0.9761 - val_loss: 2.8351 - val_acc: 0.5366
#
# Epoch 00100: val_loss did not improve from 1.62014
# Traing finished.
# Loading the best model...
# Best Model loaded!

# %% [markdown]
# ### Test the model

# %%
score = model.evaluate(images_test, labels_one_hot_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.6511499529741307
# Test accuracy: 0.5372907154182683

# %% [markdown]
# ### Examine training process

# %%
print(results)
# Out:
# <keras.callbacks.History object at 0x7f06a858c1d0>

# %%
from matplotlib import pyplot as plt

# summarize history for accuracy
plt.plot(results.history['acc'])
plt.plot(results.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid.'], loc='upper right')
plt.show()
