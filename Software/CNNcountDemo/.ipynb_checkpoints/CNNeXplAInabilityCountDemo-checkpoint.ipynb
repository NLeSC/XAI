# %% [markdown]
# # CNN Explainability Count Demo
#
# *At the moment this is work in progress and in the experimental phase. If the experiment is successsful, e.g. we get meaningful heatmaps for the task, this will turn into a real demo!*
#
# **The purpose of this demo is to show the ability of DNN explainability method(s) to generate meanfingful heatmaps for the relevance of the input image pixels to the output resut of a CNN model. The task is chosen to be counting shapes rather than a classical object classificaiton task to minimize human interpretation of the resulting heatmaps.**
#
# The explainability tool [iNNvestigate](https://github.com/albermax/innvestigate) is chosen as it offers open source implementatons of several explainability methods. Since it supports [Keras](https://keras.io/), the framework (with [Tensorflow](https://www.tensorflow.org/) as backend) is used to genrate the CNN model(s), though our vision is to go for at least [PyTorch](https://pytorch.org/) deep learning library and the related [Captum](https://captum.ai/) explainability library and definitely towards using DNN model standards such as [ONNX](https://onnx.ai/). This [list of explainability tools](https://github.com/NLeSC/XAI/blob/master/State-of-the-art/AI_Explainability_OSTools.docx) sumamrizes the availability of explainability tools.
#
# This notebook describes the Counting simple shapes (circles, squares or diamonds) experiment (see the project [Counting Binary Objects](https://github.com/NLeSC/XAI/projects/8) from the [git repo](https://github.com/NLeSC/XAI/tree/master/Software/CNNcountDemo)) and gives links to notebooks performng spesific tasks or experiments.
#
# The 'CNNCountDemo' code is in a [git repository](https://github.com/NLeSC/XAI/tree/master/Software/CNNcountDemo).
# Code from [Keras documentation example](https://keras.io/examples/mnist_cnn/) has been used as a starting point for the  CNN model.
#
# The 4 variants of the CNN model have been trained on binary images containing simple shapes- circles, diamonds and squares (obtained via the morphological structural elements of the image processing pytnon library [skimage](https://scikit-image.org/))

# %% [markdown]
# ## Data generation
#
# There are 5 different datasets of binary images for the purposes of this experiment:
#
#
# **Dataset1 containing images with circular shapes with the same radius.**
#
# **Dataset2 containing images with diamond shapes with different radii.**
#
# **Dataset3 containing images with circular, diamond and square shapes with the same size/radius.**
#
# **Dataset4 containing images with circular, diamond and square shapes with different sizes/radii.**
#
# -----
# **Dataset1Var containing images with circular shapes with different radii, which vary in larger limits.**
#
#
#
# The notebook [GenerateShapeImages](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/GenerateShapeImages.ipynb) is used to (re)generate the datasets. Please, note that if the geenrated files are deleted and the notebook ran again, the new dataset will be different that the original as many generation parameters are random (the location of the shapes is always random).
#
# The number of shapes per image for all datasets is a random number between 1 and 3. Therefore the classification result is one of the classes '1', '2' or '3, where the class corresponds to the shapes count in the image. Each shape is at a random location and occlusion is not allowed. For the images with different shapes, the type is chosen randomly from a circle, diamond or square.
#
# The images dimensions are 64x64 pixels and the datasets contain 60k images. Te shape size (or 'radius') is an integer number between 2 and 6 pixels. For the shapes with the same size (radius), the average of 4 pixels is used.
#
# For the Dataset1Var, the radius can vary between 2 and 10 pixels.

# %% [markdown]
# ## Model training
#
# The generated data per dataset have been split in 42k for training, 12k for validaiton and 6k for testing.
# Four CNN models have been trained on each of the four datasets described above. The links to the notebooks per model training:
#
#
# **[TrainModel1CirclesSameRadius](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TrainModel1CirclesSameRadius.ipynb) for Model1 trained on Dataset1.**
#
# **[TrainModel2DiamondsDiffSize](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TrainModel2DiamondsDiffSIze.ipynb) for Model2 trained on Dataset2.**
#
# **[TrainModel3DiffShapesSameSize](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TrainModel3DiffShapesSameSize.ipynb) for Model3 trained on Dataset3.**
#
# **[TrainModel4DiffShapesDiffSIze](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TrainModel4DiffShapesDiffSIze.ipynb) for Model4 trained on Dataset4.**
#
# ------------------------
#
# **[TrainModel1CirclesDiffRadiiVar](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TrainModel1CirclesDiffRadiiVar.ipynb) for Model1Var trained on Dataset1Var.**
#
# The obtained accuracies are as follows:
#
# Model1: Train: 99.97%, Validation: 100%
#
# Model2: Train: 97.27%, Validation: 99.02%
#
# Model3: Train: 99.05% , Validation: 100%
#
# Model4: Train: 98.22%, Validation: 98.98%
#
# ------------------
#
# Model1Var: Train:95.07%, Validation: 98.09%

# %% [markdown]
# ## Model testing
#
# The links to the notebooks per model testing:
#
#
# **[TestModel1Dataset1](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel1Dataset1.ipynb) for testing Model1 (trained on Dataset1) on Dataset1.**
#
# **[TestModel1Dataset2](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel1Dataset2.ipynb) for testing Model1 (trained on Dataset1) on Dataset2.**
#
# **[TestModel1Dataset3](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel1Dataset3.ipynb) for testing Model1 (trained on Dataset1) on Dataset3.**
#
# **[TestModel1Dataset4](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel1Dataset4.ipynb) for testing Model1 (trained on Dataset1) on Dataset4.**
#
# -----------------------------
# **[TestModel2Dataset1](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel2Dataset1.ipynb) for testing Model2 (trained on Dataset2) on Dataset1.**
#
# **[TestModel2Dataset2](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel2Dataset2.ipynb) for testing Model2 (trained on Dataset2) on Dataset2.**
#
# **[TestModel2Dataset3](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel2Dataset3.ipynb) for testing Model2 (trained on Dataset2) on Dataset3.**
#
# **[TestModel2Dataset4](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel2Dataset4.ipynb) for testing Model2 (trained on Dataset2) on Dataset4.**
#
# -----------------------------
#
# **[TestModel3Dataset1](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel3Dataset1.ipynb) for testing Model3 (trained on Dataset3) on Dataset1.**
#
#
# **[TestModel3Dataset2](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel3Dataset2.ipynb) for testing Model3 (trained on Dataset3) on Dataset2.**
#
#
# **[TestModel3Dataset3](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel3Dataset3.ipynb) for testing Model3 (trained on Dataset3) on Dataset3.**
#
# **[TestModel3Dataset4](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel3Dataset4.ipynb) for testing Model3 (trained on Dataset3) on Dataset4.**
#
# ---------------------------
# **[TestModel4Dataset1](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel4Dataset4.ipynb) for testing Model4 (trained on Dataset4) on Dataset1.**
#
# **[TestModel4Dataset2](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel4Dataset2.ipynb) for testing Model4 (trained on Dataset4) on Dataset2.**
#
# **[TestModel4Dataset3](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel4Dataset3.ipynb) for testing Model4 (trained on Dataset4) on Dataset3.**
#
# **[TestModel4Dataset4](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel4Dataset4.ipynb) for testing Model4 (trained on Dataset4) on Dataset4.**
#
# ----------------------
#
# **[TestModel1VarDataset1Var](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/TestModel1VarDataset1Var.ipynb) for testing Model1Var (trained on Dataset1Var) on Dataset1Var.**
#
#
# The obtained test accurasies are as follows:
#
# ------------------------
# M1D1: 100%
#
# M1D2: 61.98%
#
# M1D3: 84.38%
#
# M1D4: 65%
#
# ----------------------
# M2D1: 99%
#
# M2D2: 99%
#
# M2D3: 95%
#
# M2D4: 98%
#
# ---------------------
# M3D1: 100%
#
# M3D2: 80%
#
# M3D3: 100%
#
# M3D4: 77.50%
#
# --------------------
# M4D1: 99.80%
#
# M4D2: 97.80%
#
# M4D3: 99.78%
#
# M4D4: 98.95%
#
# -----------------
#
# M1varD2var: 98%

# %% [markdown]
# ## Explainability heatmaps
#
# The links to the notebooks for generating explainability heatmaps:
#
# --------
# Simple notebooks
#
# [Model1SingleImageSingleMethod](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1SingleImageSingleMethod.ipynb) for analyzing Model1 on a single image with a single explainability method.
#
# [Model1ManyImageSingleMethod](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1ManyImagesSingleMethod.ipynb) for analyzing Model1 on many images with a single explainability method (input times gradient).
#
# [Model1SingleImageManyMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1SingleImageManyMethods.ipynb) for analyzing Model1 on a single image with 8 explainability methods.
#
# -----------------------
# Experiments
#
# ^^^^^^^^^^^^^^^^^^^^^^
#
# **[Model1Dataset1ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1Dataset1ManyImagesSomeMethods.ipynb) for analyzing Model1 on many images of Dataset1 with 6 explainability methods.**
#
# **[Model1Dataset2ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1Dataset2ManyImagesSomeMethods.ipynb) for analyzing Model1 on many images of Dataset2 with 6 explainability methods.**
#
# **[Model1Dataset3ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1Dataset3ManyImagesSomeMethods.ipynb) for analyzing Model1 on many images of Dataset3 with 6 explainability methods.**
#
# **[Model1Dataset4ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model1Dataset4ManyImagesSomeMethods.ipynb) for analyzing Model1 on many images of Dataset4 with 6 explainability methods.**
#
# ^^^^^^^^^^^^^^^^^^^^^^
#
# **[Model2Dataset1ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model2Dataset1ManyImagesSomeMethods.ipynb) for analyzing Model2 on many images of Dataset1 with 6 explainability methods.**
#
# **[Model2Dataset2ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model2Dataset2ManyImagesSomeMethods.ipynb) for analyzing Model2 on many images of Dataset2 with 6 explainability methods.**
#
# **[Model2Dataset3ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model2Dataset3ManyImagesSomeMethods.ipynb) for analyzing Model2 on many images of Dataset3 with 6 explainability methods.**
#
# **[Model2Dataset4ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model2Dataset4ManyImagesSomeMethods.ipynb) for analyzing Model2 on many images of Dataset4 with 6 explainability methods.**
#
# ^^^^^^^^^^^^^^^^^^^^^^
#
# **[Model3Dataset1ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model3Dataset1ManyImagesSomeMethods.ipynb) for analyzing Model3 on many images of Dataset1 with 6 explainability methods.**
#
# **[Model3Dataset2ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model3Dataset2ManyImagesSomeMethods.ipynb) for analyzing Model3 on many images of Dataset2 with 6 explainability methods.**
#
# **[Model3Dataset3ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model3Dataset3ManyImagesSomeMethods.ipynb) for analyzing Model3 on many images of Dataset3 with 6 explainability methods.**
#
# **[Model3Dataset4ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model3Dataset4ManyImagesSomeMethods.ipynb) for analyzing Model3 on many images of Dataset4 with 6 explainability methods.**
#
# ^^^^^^^^^^^^^^^^^^^^^^
#
# **[Model4Dataset1ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model4Dataset1ManyImagesSomeMethods.ipynb) for analyzing Model4 on many images of Dataset1 with 6 explainability methods.**
#
# **[Model4Dataset2ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model4Dataset2ManyImagesSomeMethods.ipynb) for analyzing Model4 on many images of Dataset2 with 6 explainability methods.**
#
# **[Model4Dataset3ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model4Dataset3ManyImagesSomeMethods.ipynb) for analyzing Model4 on many images of Dataset3 with 6 explainability methods.**
#
# **[Model4Dataset4ManyImagesSomeMethods](https://github.com/NLeSC/XAI/blob/master/Software/CNNcountDemo/Model4Dataset4ManyImagesSomeMethods.ipynb) for analyzing Model4 on many images of Dataset4 with 6 explainability methods.**
